# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import  xgboost
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
import statsmodels
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # IMPORTING DATA

# %%
df = pd.read_excel("C:/Users/Faayez/Downloads/Foreign Equity Market Indices.xlsx", index_col = 'Date', skiprows = [1])

# %%
df
# Out:
#             DOWJONES INDUSTRIAL AVERAGE  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# Date
# 2024-04-19                     37801.98    37986.40    38102.57    37781.61
# 2024-04-18                     37847.21    37775.38    38083.76    37681.52
# 2024-04-17                     37949.67    37753.31    38036.70    37611.56
# 2024-04-16                     37992.22    37798.97    37992.22    37713.70
# 2024-04-15                     38075.38    37735.11    38386.81    37657.79
# ...                                 ...         ...         ...         ...
# 2003-03-07                      7671.75     7740.03     7743.82     7562.65
# 2003-03-06                      7774.76     7673.99     7777.42     7659.09
# 2003-03-05                      7702.35     7775.60     7775.60     7661.32
# 2003-03-04                      7838.14     7704.87     7845.71     7704.31
# 2003-03-03                      7890.24     7837.86     7981.46     7822.73
#
#             NASDAQ-100 INDEX  Unnamed: 6  Unnamed: 7  Unnamed: 8
# Date
# 2024-04-19          17334.71    17037.65    17362.28    16973.94
# 2024-04-18          17514.77    17394.31    17590.81    17376.49
# 2024-04-17          17785.82    17493.62    17788.54    17459.57
# 2024-04-16          17691.45    17713.66    17817.73    17660.89
# 2024-04-15          18143.26    17706.83    18152.08    17676.35
# ...                      ...         ...         ...         ...
# 2003-03-07            967.93      986.82      992.11      964.25
# 2003-03-06            982.04      983.96      991.69      976.55
# 2003-03-05            981.67      990.23      995.19      978.40
# 2003-03-04            991.60      982.98      994.35      982.06
# 2003-03-03           1015.87      991.07     1023.47      988.40
#
# [5211 rows x 8 columns]

# %%
df = df.iloc[:, 0:4]

# %%
df.rename(columns = {'DOWJONES INDUSTRIAL AVERAGE': 'Open', 'Unnamed: 2' : 'Close', 'Unnamed: 3': 'High', 
                     'Unnamed: 4': 'Low'}, inplace = True)

# %% [markdown]
# Note that the dataframe is in an upside down order, meaning that the dates start from today and then move to the past. Instead, we want the dataframe to begin at the earliest date and then end at the latest one.

# %%
df = df.reindex(index=df.index[::-1])

# %%
df
# Out:
#                 Open     Close      High       Low
# Date
# 2003-03-03   7890.24   7837.86   7981.46   7822.73
# 2003-03-04   7838.14   7704.87   7845.71   7704.31
# 2003-03-05   7702.35   7775.60   7775.60   7661.32
# 2003-03-06   7774.76   7673.99   7777.42   7659.09
# 2003-03-07   7671.75   7740.03   7743.82   7562.65
# ...              ...       ...       ...       ...
# 2024-04-15  38075.38  37735.11  38386.81  37657.79
# 2024-04-16  37992.22  37798.97  37992.22  37713.70
# 2024-04-17  37949.67  37753.31  38036.70  37611.56
# 2024-04-18  37847.21  37775.38  38083.76  37681.52
# 2024-04-19  37801.98  37986.40  38102.57  37781.61
#
# [5211 rows x 4 columns]

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 6))

# Loop through axes and plot data with titles
for i, ax in enumerate(axes.flatten()):
    data = df[df.columns[i]]
    ax.plot(data, color='red')

    # Set chart title using ax.set_title()
    ax.set_title(df.columns[i])  # Use the corresponding column name as title

# %% [markdown]
# Now let us check if there are any missing values in the data

# %%
null_mask = df.isnull().any(axis=1)

# %%
df[null_mask]
# Out:
#                 Open  Close      High       Low
# Date
# 2006-05-17  11410.13    NaN  11410.13  11174.38

# %%
df['Close']= df['Close'].fillna(method ='bfill')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5211 entries, 2003-03-03 to 2024-04-19
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5211 non-null   float64
#  1   Close   5211 non-null   float64
#  2   High    5211 non-null   float64
#  3   Low     5211 non-null   float64
# dtypes: float64(4)
# memory usage: 203.6 KB

# %% [markdown]
# # BASELINE MODEL

# %% [markdown]
# Let us make a persistence model to be used as a baseline model to use as a reference for our further models. This model will simply  use the last period's value to predict the next value. Also, this would be a univariate model

# %%
df_baseline = pd.DataFrame(df['Close'])

# %%
df_baseline['Close_lag'] = df_baseline['Close'].shift(+1)

# %%
df_baseline
# Out:
#                Close  Close_lag
# Date
# 2003-03-03   7837.86        NaN
# 2003-03-04   7704.87    7837.86
# 2003-03-05   7775.60    7704.87
# 2003-03-06   7673.99    7775.60
# 2003-03-07   7740.03    7673.99
# ...              ...        ...
# 2024-04-15  37735.11   37983.24
# 2024-04-16  37798.97   37735.11
# 2024-04-17  37753.31   37798.97
# 2024-04-18  37775.38   37753.31
# 2024-04-19  37986.40   37775.38
#
# [5211 rows x 2 columns]

# %%
def model_persistence(x):
    return x

# %%
baseline_scaler = StandardScaler()
scaled_baseline = baseline_scaler.fit_transform(df_baseline)

# %%
df_baseline_scaled = pd.DataFrame(scaled_baseline, columns = df_baseline.columns, index = df_baseline.index )

# %%
df_baseline_scaled.dropna()
# Out:
#                Close  Close_lag
# Date
# 2003-03-04 -1.225184  -1.210043
# 2003-03-05 -1.217114  -1.225224
# 2003-03-06 -1.228708  -1.217150
# 2003-03-07 -1.221172  -1.228749
# 2003-03-10 -1.240781  -1.221210
# ...              ...        ...
# 2024-04-15  2.201372   2.230963
# 2024-04-16  2.208659   2.202640
# 2024-04-17  2.203449   2.209930
# 2024-04-18  2.205967   2.204718
# 2024-04-19  2.230045   2.207237
#
# [5210 rows x 2 columns]

# %%
train_size = int((len(df_baseline_scaled)*0.8))
train, test = df_baseline_scaled[1:train_size], df_baseline_scaled[train_size:]

# %%
trainX = train['Close_lag']
trainY = train['Close']

# %%
testX= test['Close_lag']
testY = test['Close']

# %%
# walk-forward validation
predictions = list()
for x in testX:
    yhat = model_persistence(x)
    predictions.append(yhat)
test_score = mean_squared_error(testY, predictions, squared = False)
print('Test MSE: %.3f' % test_score)
# Out:
# Test MSE: 0.043

# %%
pred = pd.DataFrame(predictions)
pred = pred.set_index(testY.index, 'Date')
pred = pred.rename(columns = {0: 'Predictions'})

# %%
plt.plot(pred, color = 'blue', label = 'Predicted Market Index')
plt.plot(testY, color = 'red', label = 'Real Market Index')
plt.title('Market Index Prediction')
plt.xlabel('Time')
plt.xticks(rotation='vertical')
plt.ylabel('Dow Jones Industrial Average')
plt.legend()
plt.show()

# %% [markdown]
# Therefore the persistence model is giving quite a good prediction to the market price index. The test MSE comes out to be 0.043, which is the baseline which we would want to beat.

# %% [markdown]
# # GETTING THE RIGHT MODELS

# %% [markdown]
# For our case, we will be training the following models:
#
# 1. ARIMA
# 2. Linear Regression
# 2. Support vector regressor
# 3. XGBoost
# 4. LSTM
# 5. GRU

# %% [markdown]
# ### 1. ARIMA

# %%
plt.plot(df['Close'])

# %% [markdown]
# The series clearly reflects and upward trend and also kind of clustered volatility. Therefore, it is appropriate to use an ARIMA model to capture the trend in the series.

# %%
df_arima = pd.DataFrame(df['Close'], columns = ['Close'])

# %%
df_arima
# Out:
#                Close
# Date
# 2003-03-03   7837.86
# 2003-03-04   7704.87
# 2003-03-05   7775.60
# 2003-03-06   7673.99
# 2003-03-07   7740.03
# ...              ...
# 2024-04-15  37735.11
# 2024-04-16  37798.97
# 2024-04-17  37753.31
# 2024-04-18  37775.38
# 2024-04-19  37986.40
#
# [5211 rows x 1 columns]

# %%
def ad_test(dataset):
    dftest = adfuller(dataset, autolag = 'AIC')
    print('1. ADF:', dftest[0])
    print('2. P-Value:', dftest[1])
    print('3. Number of lags:', dftest[2])
    print('4. Number of observations used for ADF Regression and critical values calculation:', dftest[3])
    print('5. Critical Values:')
    for key, val in dftest[4].items():
        print('\t', key, ':', val)

# %%
ad_test(df_arima)
# Out:
# 1. ADF: 0.25948674813445216
# 2. P-Value: 0.9754074751743668
# 3. Number of lags: 12
# 4. Number of observations used for ADF Regression and critical values calculation: 5198
# 5. Critical Values:
# 	 1% : -3.431608663381847
# 	 5% : -2.8620961977733677
# 	 10% : -2.567066063947702

# %% [markdown]
# So, the series is clearly non stationary because the p-value is greater than 0.05.

# %% [markdown]
# #### 1. Usual train-test split

# %% [markdown]
# Figure out order for ARIMA model:

# %%
# We will use auto arima because it has the stepwise fit method which allows us to directly get the best model parameters, 
# thereby saving time on fine tuning
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA

# %%
train_size = int((len(df_arima)*0.8))
train = df_arima[:train_size]
test = df_arima[train_size:]

train.shape, test.shape
# Out:
# ((4168, 1), (1043, 1))

# %%
stepwise_fit = auto_arima(df_arima, trace = True, supress_warnings = True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=75015.003, Time=2.51 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=75533.613, Time=0.20 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=75519.483, Time=0.51 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=75500.164, Time=0.56 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=75533.120, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=75043.970, Time=1.75 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=75100.951, Time=1.83 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=74996.661, Time=3.78 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=75079.372, Time=4.82 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=74998.260, Time=5.02 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=74997.907, Time=5.68 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=74997.451, Time=5.10 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=75063.185, Time=3.59 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=74999.825, Time=8.11 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=74998.926, Time=1.28 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0] intercept
# Total fit time: 44.857 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 5211
# Model:               SARIMAX(3, 1, 2)   Log Likelihood              -37491.330
# Date:                Mon, 06 May 2024   AIC                          74996.661
# Time:                        20:18:40   BIC                          75042.569
# Sample:                             0   HQIC                         75012.717
#                                - 5211
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      9.3656      5.937      1.577      0.115      -2.271      21.002
# ar.L1         -0.4113      0.020    -20.684      0.000      -0.450      -0.372
# ar.L2          0.1425      0.014     10.377      0.000       0.116       0.169
# ar.L3         -0.1038      0.010    -10.703      0.000      -0.123      -0.085
# ma.L1          0.3371      0.020     16.707      0.000       0.298       0.377
# ma.L2         -0.4866      0.014    -35.291      0.000      -0.514      -0.460
# sigma2      1.053e+05    168.761    624.147      0.000    1.05e+05    1.06e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):         106605013.04
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.11   Skew:                            -9.82
# Prob(H) (two-sided):                  0.00   Kurtosis:                       703.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Make predictions using walk forward validation
predictions = []
for i in range(len(test)):
    arima_model = ARIMA(train['Close'], order = (3, 1, 2))
    arima_fit = arima_model.fit()
    start = len(train)
    end = start + 1
    pred_arima = np.array(arima_fit.predict(start = start, end = end).iloc[-1]) 
    # np.array because arima outputs a pandas series 
    # For ARIMA, the model predicts the future value by simply using the values from the past, so we do not need to
    # supply 'x' and 'y' like we do in any other machine learning model
    train = train.append(test.iloc[i])
    predictions.append(pred_arima) # Append the prediction to the list
    print(pred_arima)
error =  mean_squared_error(test, predictions, squared = False)

print('Error for the model is', error)
# Out:
# 27874.848765879837
# 27088.185237765945
# 26695.788799108184
# 26897.548276196947
# 26377.672683267523
# 26986.174130145148
# 26309.8855562808
# 26417.82445547114
# 25154.09007154319
# 25665.365237752056
# 24427.29334569229
# 23424.542700793656
# 23688.09419830493
# 21852.58777510056
# 22146.29160884319
# 20879.73982471679
# 20815.483507265577
# 19933.751497984635
# 19464.19677235669
# 20209.446241761456
# 20433.671527517607
# 21372.790400169357
# 21214.328510380336
# 21835.201421114478
# 21725.91015706385
# 21361.822219910173
# 21529.7322610652
# 21259.92257252605
# 22039.471923184676
# 22093.794193250553
# 22719.113260044967
# 23037.849366269933
# 23114.97341741825
# 23526.92822391666
# 23408.87585202387
# 23503.76624824523
# 23874.9376178457
# 23639.667996960165
# 23385.204951861022
# 23624.295239913346
# 23504.581595356132
# 23657.88474631941
# 23855.116855313125
# 23913.05541876918
# 24257.607940269987
# 24199.610055403304
# 23968.305027664897
# 23945.98591549175
# 23937.696576396884
# 23793.267553586724
# 23875.368390237098
# 24084.866813767487
# 24080.010339664128
# 23910.864428971043
# 23636.27656625127
# 23732.920326728054
# 23683.61673863839
# 24149.651882160055
# 24021.7970147682
# 24329.286857500527
# 24319.69504684004
# 24396.77805193711
# 24681.627185923022
# 25041.750677143777
# 25094.877055564026
# 25226.177166936566
# 25324.922280483577
# 25518.96184601399
# 25842.326688021833
# 25965.62387971534
# 26514.22050257134
# 26902.78174114739
# 26964.515049276255
# 26967.89549112909
# 26027.589194377084
# 26125.395516902565
# 25946.725443177
# 26156.3749531089
# 26049.468926001533
# 26090.048258196235
# 25965.075127912223
# 26045.019534457468
# 26075.860492648248
# 25737.57658336822
# 25845.178940128768
# 25400.864378500828
# 25631.338912156105
# 25666.7206047071
# 25668.7044262962
# 25742.826868518572
# 26008.931237751967
# 25857.218483252156
# 26007.940643821803
# 25816.70311736664
# 26011.53791358479
# 25994.352153497362
# 26327.39077570781
# 26498.83258904082
# 26556.584864643748
# 26596.773085920133
# 26642.998845339647
# 26733.565283450906
# 26849.190209875578
# 26703.47574104183
# 26630.015780447597
# 26641.988463246067
# 26505.5077154162
# 26559.7113422251
# 26418.88184623057
# 26462.252635080815
# 26558.981171330117
# 26661.99710916509
# 26902.24823205681
# 27075.084649642788
# 27199.580612226047
# 27471.12880167247
# 27501.192132505086
# 27737.192764693846
# 27753.817853525878
# 27838.926499464364
# 27821.19541836541
# 27807.971968058802
# 27755.017264431433
# 27767.65696225831
# 27848.85615154282
# 28061.149656444388
# 28083.21590509672
# 28199.967286289306
# 28322.099555656045
# 28459.00741232905
# 28396.92645607876
# 28549.1070965112
# 28798.232825865434
# 28448.099455839303
# 28387.808866530646
# 27970.972932201552
# 28090.851571603722
# 27768.694549390504
# 27797.535530916706
# 27897.341630552237
# 27909.317547381015
# 27956.01136577803
# 27917.435073666034
# 27792.792646630547
# 27501.363823233052
# 27489.6802395035
# 27121.842771429154
# 27067.125189864986
# 27151.409837928124
# 27342.112427006647
# 27321.632532085954
# 27561.29987477903
# 27626.52616313878
# 27628.98076614727
# 27905.251914906083
# 27754.22023434685
# 28079.7508719512
# 28172.952812562376
# 28346.594010047505
# 28551.043696119475
# 28555.257457892312
# 28529.304983906037
# 28531.021816624583
# 28576.532138508755
# 28360.775734900042
# 28398.976718938055
# 28299.76782830971
# 28358.449561997262
# 27984.39847207473
# 27824.786695182604
# 27201.51085721944
# 27115.127838285684
# 26830.810070046835
# 26954.93272299272
# 27189.13180294773
# 27448.614778618743
# 27848.175802413436
# 27968.543127047466
# 28556.784183950433
# 28846.858256181462
# 29030.593459744723
# 29000.260155968223
# 29282.545525366357
# 29571.599323243565
# 29583.684893189158
# 29490.784580870044
# 29530.65660833788
# 29386.81090236597
# 29540.767855693368
# 29769.644677373282
# 29739.730927293473
# 29828.715441239045
# 29709.714134199054
# 29810.536068956328
# 29827.52824920804
# 29891.57484077874
# 30045.91596713964
# 30008.54920967132
# 30103.711216055526
# 30062.94284439914
# 30076.994680265358
# 30060.40686609756
# 29958.475944605925
# 30121.44833163986
# 30092.595919711963
# 30203.304060246624
# 30157.95720039525
# 30201.34466196752
# 30092.259092879045
# 30147.39735938473
# 30163.60109796755
# 30283.950832992887
# 30269.990976539644
# 30345.708277635556
# 30466.2518677608
# 30296.51833757532
# 30396.80813005693
# 30613.816277717222
# 30767.715357066292
# 30884.198475263976
# 30913.150261202358
# 30992.534761927975
# 31010.808485506463
# 30994.606458550777
# 30903.739201383793
# 30887.74730133567
# 30920.841446994124
# 31053.154745470645
# 31071.88152285066
# 31018.407765067856
# 31007.21118427877
# 30980.685841320494
# 30622.397169885386
# 30726.90279416615
# 30308.004825981727
# 30374.20011946205
# 30538.472238666207
# 30574.29209196309
# 30804.469101554703
# 30921.58545027297
# 31126.873238526798
# 31199.341056069257
# 31301.723352667384
# 31344.68299912062
# 31393.682085638877
# 31450.928467560672
# 31521.337726522186
# 31482.873903045816
# 31499.90971731503
# 31511.7150803099
# 31521.99313177642
# 31756.356806888925
# 31489.431460819756
# 31259.444907823723
# 31503.416469743803
# 31377.920452023827
# 31333.723562380233
# 31131.632517689446
# 31397.76162970666
# 31540.606216948236
# 31632.501607710376
# 31955.905087994393
# 32146.65808358643
# 32418.704866425276
# 32626.20224000066
# 32666.8968406241
# 32846.56203542309
# 32808.38299329231
# 32719.13225667958
# 32761.15563044854
# 32572.05656203103
# 32543.21658342411
# 32603.07082573516
# 32837.40698864766
# 32936.7727047767
# 32963.336712400065
# 32966.17672246707
# 33075.310083642595
# 33291.13417285825
# 33294.05289350643
# 33366.13081939233
# 33426.3451870898
# 33613.65871761098
# 33625.92988709429
# 33642.981331733405
# 33690.76448945285
# 33868.96638443891
# 33992.22878783811
# 33992.27845563671
# 33897.17376952729
# 34066.85280142017
# 33884.84673486642
# 34018.04169128474
# 33966.60674444455
# 33985.57086486358
# 33890.52488290557
# 34014.98955674645
# 33902.453186690866
# 34045.89535810521
# 34053.22595239015
# 34141.63560491342
# 34335.07572455105
# 34516.69773146192
# 34573.67269226971
# 34388.452365115365
# 34013.98723582697
# 34155.35832670207
# 34250.89003899669
# 34241.414247168694
# 34131.578820861956
# 34044.33909024636
# 34102.17179199828
# 34145.533577733266
# 34257.59680775044
# 34248.857018450384
# 34287.60197383867
# 34377.64587581737
# 34432.544825323195
# 34464.48418596622
# 34514.773792165994
# 34547.658817325675
# 34553.044931816985
# 34662.91807447146
# 34611.84746527222
# 34616.72550337402
# 34528.14190834462
# 34524.023039639855
# 34504.64969346752
# 34448.451366603935
# 34382.75960022572
# 34215.644291524564
# 34055.551786904995
# 33693.71362023648
# 33911.084828472034
# 33871.98822502496
# 33859.838904557124
# 34045.26357507428
# 34204.11368751887
# 34186.106225197436
# 34246.91527532277
# 34375.99700959656
# 34478.077686062345
# 34608.15317775058
# 34549.48433593048
# 34638.706140286224
# 34501.90328098318
# 34743.83509794544
# 34813.599835701556
# 34817.925515573486
# 34878.079001557526
# 34926.87318461578
# 34779.443891709794
# 34379.00176272932
# 34588.42402855064
# 34656.66507676131
# 34700.097046039045
# 34874.311213542795
# 34970.06016454331
# 34982.50500580129
# 34952.0142144472
# 35039.95637175098
# 34960.22640180841
# 34913.28650769152
# 35044.80738273196
# 34867.73901051296
# 35021.07816159987
# 35086.41943886708
# 35064.64655304092
# 35176.747343345596
# 35316.5124693762
# 35367.39412158187
# 35427.87996367686
# 35519.41926377884
# 35396.46996036221
# 35194.73693747229
# 35105.10082898568
# 35152.07501402819
# 35235.01006524273
# 35269.514572399275
# 35326.2098690815
# 35247.48218330964
# 35387.150517657916
# 35356.9026881042
# 35360.62047954631
# 35335.70022931685
# 35405.527299804024
# 35404.89800140619
# 35381.73698822367
# 35235.01010416207
# 35173.83890761779
# 35039.297111509644
# 34845.74921296173
# 34921.53792898613
# 34715.1746693615
# 34821.78563226266
# 34757.987471574095
# 34673.735400450845
# 34316.27908608596
# 34218.16357672612
# 34287.261016180244
# 34522.56001104171
# 34581.24489728175
# 34705.887153686024
# 34446.72566158087
# 34501.76247111068
# 34143.05533566661
# 34353.31542578407
# 34107.88038614045
# 34280.21634452828
# 34308.34941411761
# 34535.16153844059
# 34572.904787952575
# 34512.67875140928
# 34459.96263657646
# 34445.73459443433
# 34707.47997665313
# 34946.17889548624
# 35020.728563219294
# 35230.40565267853
# 35378.922656836214
# 35453.79666204437
# 35551.191490500736
# 35630.44781208005
# 35674.29617608768
# 35560.077992963925
# 35691.58508559488
# 35730.45252234943
# 35809.45584937096
# 35916.19698788813
# 36014.26598681397
# 36040.88730704753
# 36190.40400121706
# 36279.68348067584
# 36268.77332851966
# 36167.40375395102
# 36071.177730210664
# 36126.07031819107
# 36090.45436738185
# 36121.2883522909
# 36006.8825232425
# 35966.94322475767
# 35785.47143426585
# 35752.38672827916
# 35802.93879769908
# 35783.7006696573
# 35292.86694973096
# 35364.844765066344
# 34882.997757259946
# 34543.63560868325
# 34718.85353743354
# 34594.60848361273
# 34952.91694395297
# 35267.22995806525
# 35415.40855209186
# 35544.227039109246
# 35746.70535772755
# 35634.102431546264
# 35615.38854659661
# 35808.40475162393
# 35800.917912459394
# 35547.17308044992
# 35290.132513585304
# 35503.498075565614
# 35585.83428733535
# 35736.86381194948
# 35798.28055078505
# 36055.23295601663
# 36166.33919943009
# 36301.17179843979
# 36311.767760694696
# 36324.66738338564
# 36470.13115279712
# 36611.259057299176
# 36443.985836423686
# 36377.33818672866
# 36333.35510193321
# 36206.16545472278
# 36268.95136365514
# 36265.633185732804
# 36173.445386853826
# 36056.29836175864
# 36019.69433584317
# 35675.24833807917
# 35422.416556915756
# 35124.49279090079
# 34744.33093093394
# 34654.3034755287
# 34490.898755940565
# 34348.82074988973
# 34284.97445946115
# 34553.54706013616
# 34790.40017694983
# 35040.14309967893
# 35280.60744826276
# 35105.449604639754
# 35148.30493956845
# 35125.57767048157
# 35322.801450883846
# 35508.735496129164
# 35287.77163531822
# 35040.237493242625
# 34875.44186006188
# 35007.76566709174
# 34925.9639946306
# 34588.30253905941
# 34411.21573677674
# 34030.73442722728
# 33646.28667920625
# 33538.98610430309
# 33876.72918785978
# 33767.47198150736
# 33502.573555093506
# 33813.38148224461
# 33728.0245528367
# 33666.838130836426
# 33213.15411970226
# 33038.057256600034
# 33257.34943437779
# 33141.224502951605
# 33036.83528055355
# 33024.14307661744
# 33328.436715384276
# 33643.136990059174
# 33994.20479085922
# 34299.42896430521
# 34339.73458325496
# 34591.03643481707
# 34393.98350730014
# 34628.43944532563
# 34704.41777105698
# 34811.72368271397
# 35045.670695706925
# 35077.62807953828
# 34831.06945213362
# 34909.33066432042
# 34911.42373218852
# 34751.36511686191
# 34651.17060138774
# 34655.577822697196
# 34692.88755299487
# 34458.64906321781
# 34391.198057041205
# 34525.179694704486
# 34441.06326417075
# 34436.52848257694
# 34710.91386688818
# 34880.95428342137
# 34760.269483934506
# 34257.94566582016
# 34316.65193483227
# 33720.9089960794
# 33655.23729252739
# 33846.4742889097
# 33287.159923413084
# 33304.29060194854
# 33233.62182344592
# 33716.241461547594
# 33153.42152341416
# 33153.60024901751
# 32679.66304241508
# 32535.344400378304
# 32194.034467124515
# 32033.52974251519
# 32176.498789963145
# 32159.06484223346
# 32422.72077614319
# 31813.867158251895
# 31670.56872256839
# 31527.117276139605
# 31772.205262386764
# 31774.75867226078
# 31945.300306729278
# 32286.054146687
# 32705.245732435953
# 32720.552939123514
# 32757.20014454823
# 33043.66722329801
# 32893.09427777251
# 33088.245357886844
# 32942.80289643353
# 32596.5840057807
# 32027.62525759461
# 31359.16439714592
# 31017.978781338756
# 30944.9358405683
# 30362.02885201326
# 30240.663403637256
# 30467.75942811802
# 30401.914086632638
# 30552.755000832567
# 31061.346198657375
# 31117.58330302758
# 30973.098707884346
# 31058.13472765762
# 30891.02435069461
# 31057.362519725284
# 30963.464009422867
# 31022.17330584369
# 31218.895829672434
# 31226.050910323702
# 31180.016413691825
# 31083.771364239536
# 30940.087926992845
# 30811.81381185348
# 31133.453203148496
# 31002.640186707366
# 31493.987586209663
# 31573.703366979884
# 31791.85197568792
# 31787.32583566876
# 31906.316044186486
# 31791.312187156007
# 32062.891003296136
# 32258.335115954087
# 32525.46940378313
# 32589.530640190867
# 32451.600268796712
# 32708.295968782262
# 32659.997404256384
# 32740.242433242234
# 32775.03221649304
# 32761.80534286572
# 33084.338758169346
# 33135.4058987724
# 33465.04126373211
# 33627.20321478677
# 33872.965940246926
# 33858.35153306935
# 33941.793444049195
# 33787.53283750887
# 33413.60507487917
# 33242.96351943347
# 33159.876926379264
# 33263.151799096515
# 32652.801734545264
# 32499.474593318075
# 32167.52360997328
# 31883.095398162262
# 31839.004887798368
# 31551.13192471653
# 31385.693968459305
# 31560.549409277864
# 31635.795412472886
# 31898.043299123063
# 32096.57171855119
# 31444.148904118578
# 31454.745257060735
# 31212.476333059712
# 31050.404047128875
# 31081.913363485342
# 30855.20328578124
# 30516.18727960212
# 30370.64683889387
# 29968.68093476497
# 29668.907315019147
# 29452.306692432107
# 29660.624569409738
# 29336.780916562173
# 29048.374675052193
# 29410.113983231407
# 29853.463817692973
# 29935.254089352526
# 29881.41156227904
# 29561.812683889395
# 29464.695575469337
# 29381.641250383833
# 29305.21106569372
# 29754.84628042363
# 29548.49777333639
# 29955.323265168747
# 30188.077472851535
# 30239.951871229674
# 30269.426303431093
# 30753.40885967564
# 31055.38612328847
# 31406.816548215444
# 31550.294163228213
# 31795.969875082763
# 32368.171320926376
# 32419.46002745763
# 32522.63024815778
# 32284.818599686365
# 32193.826935687644
# 32363.840112964084
# 32590.511002828633
# 32845.63688916546
# 32560.774981903614
# 33328.323255133
# 33379.778930732136
# 33420.23617590619
# 33518.687785869486
# 33528.252962991646
# 33533.58775875465
# 33663.67413370226
# 33646.03764183672
# 33916.90772966672
# 34004.56730200139
# 34174.3857423264
# 33930.39226852231
# 33957.41843571479
# 34343.419216740345
# 34259.89482494884
# 34359.4967328649
# 34099.009155300126
# 33876.66847810125
# 33791.90505629357
# 33817.02522990293
# 33598.82039312491
# 33895.84992298208
# 33944.145906972895
# 33924.44599192816
# 33498.987471756824
# 33289.47802775922
# 33055.95788178561
# 33003.301060603604
# 33236.77984783822
# 33034.70859140116
# 33174.56111043061
# 33189.61525694023
# 32990.97496414086
# 33186.33358893364
# 33118.36256417643
# 33135.11245521689
# 33213.81068669816
# 33022.93556593599
# 33436.641065233554
# 33375.977317388286
# 33565.0081594873
# 33761.43988165811
# 33958.21140583665
# 34099.8787931502
# 33944.76847750191
# 33603.28634912414
# 33387.415987406195
# 33461.676132164095
# 33541.89218329499
# 33614.40710855804
# 33661.58640584271
# 33818.347497532835
# 33869.93794904228
# 33757.833412286076
# 33989.11877040892
# 33993.63755279709
# 34015.135062718145
# 33957.15393300995
# 33938.79724785178
# 34078.47062234944
# 33960.91995060547
# 33829.18564766937
# 33901.27742564618
# 34093.4074421947
# 34025.65254679732
# 34094.08874192057
# 33845.39112541808
# 33907.67673612749
# 33438.26878595249
# 33334.61146975063
# 33277.47459247922
# 33015.75390215249
# 33005.44863919539
# 32810.101625833544
# 32770.499495021955
# 32928.11757804711
# 33155.25748413513
# 33240.83551963941
# 32974.39265220854
# 32951.75659311059
# 32563.198281759152
# 32284.96286868298
# 32101.56741956687
# 32195.048556654037
# 31969.344408855606
# 32187.193784420317
# 31936.066470126854
# 32182.150816963007
# 32349.54552974584
# 32096.487174936705
# 32164.076235634635
# 32212.93155489821
# 32323.784203647952
# 32329.119518935775
# 32553.925148917802
# 32675.150027458116
# 32989.27387081717
# 33263.971086371115
# 33256.39973396327
# 33389.17363409632
# 33421.571200500926
# 33510.96797402229
# 33590.77714968885
# 33599.17199259795
# 33853.70348148337
# 33802.56045561656
# 33916.637568213635
# 33927.809348466995
# 33904.56159492327
# 33841.320542899884
# 33844.58613419612
# 33864.80432678486
# 33656.6533457786
# 33500.4419143341
# 33754.16565533838
# 33891.31999793916
# 33926.589222330374
# 33763.46122319354
# 33607.865390951025
# 33378.16262708072
# 33631.26446895286
# 33554.175307661
# 33558.97033378293
# 33543.35644450005
# 33411.97624080464
# 33382.88460547582
# 33379.23206720784
# 33156.363134137144
# 33378.44724470198
# 33417.96034999777
# 33395.92523433107
# 33332.84345751962
# 33192.19650157459
# 33001.05950334006
# 32922.64778393235
# 33053.04032143129
# 33006.6175666227
# 32946.35154059891
# 33036.95200416851
# 33451.807149872264
# 33390.79532525301
# 33495.6396628376
# 33580.336136433776
# 33711.29118623062
# 33769.90924710543
# 33928.3640702369
# 34053.27369400231
# 33968.85782393875
# 34255.4776467596
# 34209.597537335314
# 34114.607168974566
# 34051.28540105542
# 34016.95085852109
# 34091.612709128996
# 34258.39503969595
# 34298.47682262133
# 34272.66308801333
# 34072.02822437899
# 33934.83974186357
# 33992.59626205567
# 34140.5830994853
# 34210.04870614343
# 34290.38729790776
# 34398.26076400316
# 34480.80346713201
# 34738.42085684881
# 34857.45716021009
# 35034.32825606091
# 35100.32212338658
# 35267.857748189155
# 35325.20998061973
# 35423.13632579766
# 35311.41125940199
# 35433.622989214055
# 35482.95551695219
# 35551.714769464954
# 35365.70173904439
# 35330.3449813133
# 35192.89780633625
# 35403.191087653184
# 35289.122252325054
# 35207.78640756754
# 35218.45029796102
# 35261.520934711334
# 35271.09070363027
# 35069.62567569943
# 34943.95184721009
# 34711.102373988026
# 34653.96352002667
# 34561.50544865911
# 34417.10808649956
# 34491.33519970424
# 34236.433041358374
# 34368.84154348918
# 34457.28781548188
# 34659.68232613447
# 34731.76897096947
# 34699.01955671883
# 34794.44778486144
# 34684.2259689536
# 34566.10139273546
# 34569.18573770866
# 34577.713643122705
# 34622.73413976365
# 34619.58222178984
# 34591.578649150084
# 34791.64852491512
# 34631.49987497788
# 34662.439432022045
# 34578.22351490837
# 34519.40752989975
# 34267.13958989961
# 34159.55911244644
# 34108.2360906004
# 33826.92728343259
# 33734.94350242468
# 33731.746328856934
# 33593.696270573615
# 33529.3686330776
# 33232.71469160946
# 33257.24524736814
# 33177.716926349036
# 33331.169341166446
# 33449.083068002175
# 33581.34596038986
# 33672.7089385815
# 33621.309217499416
# 33666.11531627813
# 33855.320632868206
# 33884.219077007045
# 33733.61695285352
# 33586.30623746499
# 33364.89796256531
# 33175.21364460854
# 33215.86945775086
# 33095.65909915385
# 32930.19652365497
# 32669.112034638416
# 32910.14806051894
# 32934.24391293108
# 33112.14542009692
# 33497.72824400978
# 33724.688084727466
# 33867.63125607225
# 34000.7795904795
# 34034.82260123369
# 33940.8773606943
# 34180.00620194732
# 34215.83487667902
# 34563.408807818196
# 34723.95754783057
# 34799.61165665429
# 34867.659691230125
# 35029.031812391564
# 35020.33854338775
# 35172.71464797435
# 35265.33451908306
# 35276.40192066127
# 35356.59322392779
# 35384.05391389524
# 35719.4234802506
# 35945.0717986583
# 36022.61192628824
# 36059.389825071834
# 36054.334189908055
# 36100.418193103265
# 36180.45732164409
# 36292.21165614313
# 36430.77878565287
# 36790.790363399035
# 36964.232262176854
# 37110.98196283824
# 37190.83146738069
# 37398.54517468913
# 37148.71290847528
# 37372.24761606721
# 37334.32543593478
# 37463.08462768771
# 37544.672438281916
# 37620.879725315244
# 37637.85649974007
# 37683.29486446655
# 37516.372103457674
# 37519.64615153867
# 37493.88982289477
# 37615.59519060715
# 37521.06981365097
# 37649.59357118681
# 37655.55605234097
# 37611.75530568345
# 37470.09054664266
# 37392.99666030415
# 37466.22596311479
# 37689.7760965963
# 37805.81972410548
# 37822.96498176662
# 37807.433496230864
# 37968.62884253447
# 38012.05501794763
# 38189.50470493359
# 38308.17843710973
# 38173.90057332961
# 38423.016223456565
# 38507.58344535658
# 38392.23024854473
# 38503.31956277625
# 38590.2141352894
# 38643.32763649532
# 38641.19319804717
# 38738.73624267906
# 38428.790685132146
# 38512.03667314683
# 38664.60060775227
# 38590.12655013401
# 38581.94293063673
# 38611.79458118064
# 38884.68848111846
# 38955.80130739796
# 38990.9749724178
# 38973.104873478114
# 38969.752017871986
# 38991.18649090666
# 39044.511585147615
# 38993.53161803625
# 38756.035233489245
# 38770.04626013827
# 38790.984129066295
# 38735.95579448436
# 38765.884337038246
# 38906.73021278315
# 38947.82204491499
# 38903.472983887485
# 38802.29326286206
# 38830.78671908883
# 38998.99875646291
# 39260.09494373802
# 39493.6237868307
# 39407.103912277686
# 39373.18799691599
# 39343.81421320472
# 39612.92648634118
# 39653.09099335966
# 39573.38709360598
# 39352.26601353183
# 39290.230222025355
# 38893.49744704989
# 39011.42016728607
# 38915.88812692928
# 38907.7607238821
# 38633.18587227351
# 38607.60670769007
# 38241.69817903528
# 38032.96407429913
# 37957.2517094774
# 37855.91213017477
# 37823.20161080487
# Error for the model is 441.7483567188883

# %%
pred = pd.DataFrame(predictions, columns =['Prediction'], index = test.index)

# %%
plt.plot(pred, color = 'blue', label = 'Predicted Market Index')
plt.plot(test, color = 'red', label = 'Real Market Index')
plt.title('Market Index Prediction using ARIMA')
plt.xlabel('Time')
plt.xticks(rotation='vertical')
plt.ylabel('Dow Jones Industrial Average')
plt.legend()
plt.show()

# %% [markdown]
# So, the model does quite well on the test set, when observed graphically. But the MSE is not comparable with the baseline, because the data is not scaled here. Let us compare it with the baseline model without scaling the data.

# %%
df_baseline = pd.DataFrame(df['Close'])

# %%
df_baseline['Close_lag'] = df_baseline['Close'].shift(+1)

# %%
df_baseline
# Out:
#                Close  Close_lag
# Date
# 2003-03-03   7837.86        NaN
# 2003-03-04   7704.87    7837.86
# 2003-03-05   7775.60    7704.87
# 2003-03-06   7673.99    7775.60
# 2003-03-07   7740.03    7673.99
# ...              ...        ...
# 2024-04-15  37735.11   37983.24
# 2024-04-16  37798.97   37735.11
# 2024-04-17  37753.31   37798.97
# 2024-04-18  37775.38   37753.31
# 2024-04-19  37986.40   37775.38
#
# [5211 rows x 2 columns]

# %%
df_baseline.dropna()
# Out:
#                Close  Close_lag
# Date
# 2003-03-04   7704.87    7837.86
# 2003-03-05   7775.60    7704.87
# 2003-03-06   7673.99    7775.60
# 2003-03-07   7740.03    7673.99
# 2003-03-10   7568.18    7740.03
# ...              ...        ...
# 2024-04-15  37735.11   37983.24
# 2024-04-16  37798.97   37735.11
# 2024-04-17  37753.31   37798.97
# 2024-04-18  37775.38   37753.31
# 2024-04-19  37986.40   37775.38
#
# [5210 rows x 2 columns]

# %%
def model_persistence(x):
    return x

# %%
train_size = int((len(df_baseline)*0.8))
train, test = df_baseline[1:train_size], df_baseline[train_size:]

# %%
trainX = train['Close_lag']
trainY = train['Close']

# %%
testX= test['Close_lag']
testY = test['Close']

# %%
# walk-forward validation
predictions = list()
for x in testX:
    yhat = model_persistence(x)
    predictions.append(yhat)
test_score = mean_squared_error(testY, predictions, squared = False)
print('Test MSE: %.3f' % test_score)
# Out:
# Test MSE: 379.363

# %% [markdown]
# So, our model is performing worse than the baseline model.

# %% [markdown]
# ### 2. LINEAR REGRESSION

# %%
close_price = pd.DataFrame(df['Close'], columns = ['Close'])

# %%
df_lr = close_price
for i in range (1, 11):
    str1= 'Close_l'
    str2= str1 + str(i) 
    column = close_price.rename(columns = {'Close': str2})
    lagged_df = pd.DataFrame(column.shift(+ i))
    df_lr = pd.concat([df_lr, lagged_df], axis = 1)
df_lr = df_lr.dropna()

# %%
df_lr
# Out:
#                Close  Close_l1  Close_l2  Close_l3  Close_l4  Close_l5  \
# Date
# 2003-03-17   8141.92   7859.71   7821.75   7552.07   7524.06   7568.18
# 2003-03-18   8194.23   8141.92   7859.71   7821.75   7552.07   7524.06
# 2003-03-19   8265.45   8194.23   8141.92   7859.71   7821.75   7552.07
# 2003-03-20   8286.60   8265.45   8194.23   8141.92   7859.71   7821.75
# 2003-03-21   8521.97   8286.60   8265.45   8194.23   8141.92   7859.71
# ...              ...       ...       ...       ...       ...       ...
# 2024-04-15  37735.11  37983.24  38459.08  38461.51  38883.67  38892.80
# 2024-04-16  37798.97  37735.11  37983.24  38459.08  38461.51  38883.67
# 2024-04-17  37753.31  37798.97  37735.11  37983.24  38459.08  38461.51
# 2024-04-18  37775.38  37753.31  37798.97  37735.11  37983.24  38459.08
# 2024-04-19  37986.40  37775.38  37753.31  37798.97  37735.11  37983.24
#
#             Close_l6  Close_l7  Close_l8  Close_l9  Close_l10
# Date
# 2003-03-17   7740.03   7673.99   7775.60   7704.87    7837.86
# 2003-03-18   7568.18   7740.03   7673.99   7775.60    7704.87
# 2003-03-19   7524.06   7568.18   7740.03   7673.99    7775.60
# 2003-03-20   7552.07   7524.06   7568.18   7740.03    7673.99
# 2003-03-21   7821.75   7552.07   7524.06   7568.18    7740.03
# ...              ...       ...       ...       ...        ...
# 2024-04-15  38904.04  38596.98  39127.14  39170.24   39566.85
# 2024-04-16  38892.80  38904.04  38596.98  39127.14   39170.24
# 2024-04-17  38883.67  38892.80  38904.04  38596.98   39127.14
# 2024-04-18  38461.51  38883.67  38892.80  38904.04   38596.98
# 2024-04-19  38459.08  38461.51  38883.67  38892.80   38904.04
#
# [5201 rows x 11 columns]

# %%
lr_scaler = StandardScaler()

lr_scaled = lr_scaler.fit_transform(df_lr)

df_lr_scaled = pd.DataFrame(lr_scaled, columns = df_lr.columns, index = df_lr.index)

df_lr_scaled
# Out:
#                Close  Close_l1  Close_l2  Close_l3  Close_l4  Close_l5  \
# Date
# 2003-03-17 -1.178242 -1.210205 -1.214279 -1.244819 -1.247754 -1.242445
# 2003-03-18 -1.172270 -1.177977 -1.209942 -1.214002 -1.244553 -1.247490
# 2003-03-19 -1.164140 -1.172004 -1.177704 -1.209664 -1.213726 -1.244287
# 2003-03-20 -1.161725 -1.163871 -1.171728 -1.177416 -1.209387 -1.213451
# 2003-03-21 -1.134856 -1.161455 -1.163593 -1.171438 -1.177128 -1.209110
# ...              ...       ...       ...       ...       ...       ...
# 2024-04-15  2.200082  2.229821  2.285565  2.287234  2.336890  2.339344
# 2024-04-16  2.207373  2.201486  2.231207  2.286957  2.288633  2.338300
# 2024-04-17  2.202160  2.208778  2.202862  2.232582  2.288356  2.290028
# 2024-04-18  2.204680  2.203564  2.210157  2.204228  2.233963  2.289750
# 2024-04-19  2.228769  2.206084  2.204941  2.211525  2.205600  2.235341
#
#             Close_l6  Close_l7  Close_l8  Close_l9  Close_l10
# Date
# 2003-03-17 -1.222542 -1.229861 -1.218001 -1.225881  -1.210439
# 2003-03-18 -1.242199 -1.222304 -1.229632 -1.217782  -1.225674
# 2003-03-19 -1.247245 -1.241968 -1.222073 -1.229417  -1.217571
# 2003-03-20 -1.244041 -1.247016 -1.241744 -1.221855  -1.229211
# 2003-03-21 -1.213195 -1.243811 -1.246794 -1.241534  -1.221646
# ...              ...       ...       ...       ...        ...
# 2024-04-15  2.342083  2.308467  2.370666  2.377197   2.424238
# 2024-04-16  2.340797  2.343602  2.309981  2.372262   2.378804
# 2024-04-17  2.339753  2.342316  2.345129  2.311554   2.373867
# 2024-04-18  2.291465  2.341271  2.343842  2.346715   2.313135
# 2024-04-19  2.291187  2.292966  2.342797  2.345428   2.348310
#
# [5201 rows x 11 columns]

# %%
train_size = int((len(df_lr)*0.8))

# %%
linreg = LinearRegression()

# %%
# For making predictions:        
errors =[]
print('Results for Linear Regression ranging from lags 1 to 10 and walk forward validation')
    
for j in range(1, 11):
    
    str_name = 'Model with lags = ' 
    model_name = str_name + str(j) # Naming the model
    sample_trainX = df_lr_scaled.iloc[:train_size, 1: j+1] # Selecting all rows and columns with the current lag number indicated by the integer i
    sample_trainY = df_lr_scaled.iloc[:train_size, 0] 
    sample_testX = df_lr_scaled.iloc[train_size:, 1: j+1]
    sample_testY = df_lr_scaled.iloc[train_size:, 0] # We could have kept sample_testy outside the loop as well because it is not changing
    # We are splitting the training data in each loop because in the next loop the training data is being appended for
    # walk forward validation. So, for every next iteration we need the refreshed dataset. Note that even though the data 
    # is being refreshed we are also increasing the lags every period
    predictions = []
    for i in range(len(sample_testX)):
        linreg.fit(sample_trainX, sample_trainY)
        test_lr_X = np.array(sample_testX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
        test_lr_Y = sample_testY.iloc[i]                          # Need to reshape the test sample to
                                                                    # the shape that the model expects
        pred = linreg.predict(test_lr_X) # Make predictions
        sample_trainX = sample_trainX.append(sample_testX.iloc[i])
        sample_trainY.loc[len(sample_trainY)] = test_lr_Y 
        predictions.append(pred) # Append the prediction to the list
    error =  mean_squared_error(sample_testY, predictions, squared = False)
    print(model_name, 'has  a mean squared error of', error) 
    errors.append(error)
# Out:
# Results for Linear Regression ranging from lags 1 to 10 and walk forward validation
# Model with lags = 1 has  a mean squared error of 0.04316979015612387
# Model with lags = 2 has  a mean squared error of 0.042971698760932854
# Model with lags = 3 has  a mean squared error of 0.046705411567301756
# Model with lags = 4 has  a mean squared error of 0.046659379793646996
# Model with lags = 5 has  a mean squared error of 0.04788365817477002
# Model with lags = 6 has  a mean squared error of 0.047951880395624695
# Model with lags = 7 has  a mean squared error of 0.04815144592448791
# Model with lags = 8 has  a mean squared error of 0.04817324672555377
# Model with lags = 9 has  a mean squared error of 0.048041276112587405
# Model with lags = 10 has  a mean squared error of 0.04768269299077684

# %%
errors = pd.DataFrame(errors, columns  = ['Error'])

# %%
errors.min()
# Out:
# Error    0.042972
# dtype: float64

# %% [markdown]
# The least error occurs at lags = 2

# %%
final_trainX = df_lr_scaled.iloc[:train_size, 1: 3]
final_trainY = df_lr_scaled.iloc[:train_size, 0]
final_testX = df_lr_scaled.iloc[train_size:, 1: 3]
final_testY = df_lr_scaled.iloc[train_size:, 0]

# %%
final_trainX.shape, final_trainY.shape, final_testX.shape, final_testY.shape
# Out:
# ((4160, 2), (4160,), (1041, 2), (1041,))

# %%
linreg = LinearRegression()

# %%
predictions = []
for i in range(len(final_testX)):
    linreg.fit(final_trainX, final_trainY)
    test_lr_X = np.array(final_testX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
    test_lr_Y = final_testY.iloc[i]   # Need to reshape the test sample to the shape that the model expects
    pred = linreg.predict(test_lr_X) # Make predictions
    final_trainX = final_trainX.append(final_testX.iloc[i])
    final_trainY.loc[len(final_trainY)] = test_lr_Y
    predictions.append(pred) # Append the prediction to the list
error =  mean_squared_error(final_testY, predictions, squared = False)

print('Error for the model is', error)
# Out:
# Error for the model is 0.042971698760932854

# %%
# Inverse Scaling the predictions

predictions = np.array(predictions)
predictions_copy = np.repeat(predictions, 11, axis = -1)
pred=lr_scaler.inverse_transform(np.reshape(predictions_copy,(len(predictions),11)))[:,0]

pred_lr = pd.DataFrame(pred, columns = ['Close'])
pred_lr = pred_lr.set_index(final_testY.index, 'Date')

# %%
# Inverse scaling the original test target values

index = final_testY.index # Saving the index, because we are converting the target values to array
final_testY = np.array(final_testY)
testY_copy = np.repeat(final_testY, 11, axis = -1)
testY = lr_scaler.inverse_transform(np.reshape(testY_copy,(len(predictions),11)))[:,0]

testY_df = pd.DataFrame(testY, columns = ['Close'])
testY_df = testY_df.set_index(index, 'Date')

# %%
# pred_lr_values = pred_lr.iloc[:, 0]

plt.plot(pred_lr, color = 'blue', label = 'Predicted Market Index')
plt.plot(testY_df, color = 'red', label = 'Real Market Index')
plt.title('Market Index Prediction using Linear Regression')
plt.xlabel('Time')
plt.xticks(rotation='vertical')
plt.ylabel('Dow Jones Industrial Average')
plt.legend()
plt.show()

# %% [markdown]
# Linear Regression with only two lags is giving quite a good fit to the model with an MSE of 0.0429 which is already better than our baseline model.

# %% [markdown]
# ### 3. SVM REGRESSOR

# %%
from sklearn.svm import SVR

# %%
close_price = pd.DataFrame(df['Close'], columns = ['Close'])

# %%
df_svm = close_price
for i in range (1, 11):
    str1= 'Close_l'
    str2= str1 + str(i) 
    column = close_price.rename(columns = {'Close': str2})
    lagged_df = pd.DataFrame(column.shift(+ i))
    df_svm = pd.concat([df_svm, lagged_df], axis = 1)
df_svm = df_svm.dropna()

# %%
df_svm
# Out:
#                Close  Close_l1  Close_l2  Close_l3  Close_l4  Close_l5  \
# Date
# 2003-03-17   8141.92   7859.71   7821.75   7552.07   7524.06   7568.18
# 2003-03-18   8194.23   8141.92   7859.71   7821.75   7552.07   7524.06
# 2003-03-19   8265.45   8194.23   8141.92   7859.71   7821.75   7552.07
# 2003-03-20   8286.60   8265.45   8194.23   8141.92   7859.71   7821.75
# 2003-03-21   8521.97   8286.60   8265.45   8194.23   8141.92   7859.71
# ...              ...       ...       ...       ...       ...       ...
# 2024-04-15  37735.11  37983.24  38459.08  38461.51  38883.67  38892.80
# 2024-04-16  37798.97  37735.11  37983.24  38459.08  38461.51  38883.67
# 2024-04-17  37753.31  37798.97  37735.11  37983.24  38459.08  38461.51
# 2024-04-18  37775.38  37753.31  37798.97  37735.11  37983.24  38459.08
# 2024-04-19  37986.40  37775.38  37753.31  37798.97  37735.11  37983.24
#
#             Close_l6  Close_l7  Close_l8  Close_l9  Close_l10
# Date
# 2003-03-17   7740.03   7673.99   7775.60   7704.87    7837.86
# 2003-03-18   7568.18   7740.03   7673.99   7775.60    7704.87
# 2003-03-19   7524.06   7568.18   7740.03   7673.99    7775.60
# 2003-03-20   7552.07   7524.06   7568.18   7740.03    7673.99
# 2003-03-21   7821.75   7552.07   7524.06   7568.18    7740.03
# ...              ...       ...       ...       ...        ...
# 2024-04-15  38904.04  38596.98  39127.14  39170.24   39566.85
# 2024-04-16  38892.80  38904.04  38596.98  39127.14   39170.24
# 2024-04-17  38883.67  38892.80  38904.04  38596.98   39127.14
# 2024-04-18  38461.51  38883.67  38892.80  38904.04   38596.98
# 2024-04-19  38459.08  38461.51  38883.67  38892.80   38904.04
#
# [5201 rows x 11 columns]

# %%
svm_scaler = StandardScaler()

svm_scaled = svm_scaler.fit_transform(df_svm)

df_svm_scaled = pd.DataFrame(svm_scaled, columns = df_svm.columns, index = df_svm.index)

df_svm_scaled
# Out:
#                Close  Close_l1  Close_l2  Close_l3  Close_l4  Close_l5  \
# Date
# 2003-03-17 -1.178242 -1.210205 -1.214279 -1.244819 -1.247754 -1.242445
# 2003-03-18 -1.172270 -1.177977 -1.209942 -1.214002 -1.244553 -1.247490
# 2003-03-19 -1.164140 -1.172004 -1.177704 -1.209664 -1.213726 -1.244287
# 2003-03-20 -1.161725 -1.163871 -1.171728 -1.177416 -1.209387 -1.213451
# 2003-03-21 -1.134856 -1.161455 -1.163593 -1.171438 -1.177128 -1.209110
# ...              ...       ...       ...       ...       ...       ...
# 2024-04-15  2.200082  2.229821  2.285565  2.287234  2.336890  2.339344
# 2024-04-16  2.207373  2.201486  2.231207  2.286957  2.288633  2.338300
# 2024-04-17  2.202160  2.208778  2.202862  2.232582  2.288356  2.290028
# 2024-04-18  2.204680  2.203564  2.210157  2.204228  2.233963  2.289750
# 2024-04-19  2.228769  2.206084  2.204941  2.211525  2.205600  2.235341
#
#             Close_l6  Close_l7  Close_l8  Close_l9  Close_l10
# Date
# 2003-03-17 -1.222542 -1.229861 -1.218001 -1.225881  -1.210439
# 2003-03-18 -1.242199 -1.222304 -1.229632 -1.217782  -1.225674
# 2003-03-19 -1.247245 -1.241968 -1.222073 -1.229417  -1.217571
# 2003-03-20 -1.244041 -1.247016 -1.241744 -1.221855  -1.229211
# 2003-03-21 -1.213195 -1.243811 -1.246794 -1.241534  -1.221646
# ...              ...       ...       ...       ...        ...
# 2024-04-15  2.342083  2.308467  2.370666  2.377197   2.424238
# 2024-04-16  2.340797  2.343602  2.309981  2.372262   2.378804
# 2024-04-17  2.339753  2.342316  2.345129  2.311554   2.373867
# 2024-04-18  2.291465  2.341271  2.343842  2.346715   2.313135
# 2024-04-19  2.291187  2.292966  2.342797  2.345428   2.348310
#
# [5201 rows x 11 columns]

# %%
train_size = int((len(df_svm)*0.8))

# %%
svmreg = SVR(kernel = 'rbf')

# %%
# For making predictions:        
errors =[]
print('Results for Support Vector Regressor ranging from lags 1 to 10 and walk forward validation')
    
for j in range(1, 11):
    
    str_name = 'Model with lags = ' 
    model_name = str_name + str(j) # Naming the model
    sample_trainX = df_svm_scaled.iloc[:train_size, 1: j+1] # Selecting all rows and columns with the current lag number indicated by the integer i
    sample_trainY = df_svm_scaled.iloc[:train_size, 0] 
    sample_testX = df_svm_scaled.iloc[train_size:, 1: j+1]
    sample_testY = df_svm_scaled.iloc[train_size:, 0] # We could have kept sample_testy outside the loop as well because it is not changing
    # We are splitting the training data in each loop because in the next loop the training data is being appended for
    # walk forward validation. So, for every next iteration we need the refreshed dataset. Note that even though the data 
    # is being refreshed we are also increasing the lags every period
    predictions = []
    for i in range(len(sample_testX)):
        svmreg.fit(sample_trainX, sample_trainY)
        test_svm_X = np.array(sample_testX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
        test_svm_Y = sample_testY.iloc[i]                          # Need to reshape the test sample to
                                                                    # the shape that the model expects
        pred = svmreg.predict(test_svm_X) # Make predictions
        sample_trainX = sample_trainX.append(sample_testX.iloc[i])
        sample_trainY.loc[len(sample_trainY)] = test_svm_Y
        predictions.append(pred) # Append the prediction to the list
    error =  mean_squared_error(sample_testY, predictions, squared = False)
    print(model_name, 'has  a mean squared error of', error) 
    errors.append(error)
# Out:
# Results for Support Vector Regressor ranging from lags 1 to 10 and walk forward validation
# Model with lags = 1 has  a mean squared error of 0.06914442898344468
# Model with lags = 2 has  a mean squared error of 0.06974773798749369
# Model with lags = 3 has  a mean squared error of 0.07035783057163444
# Model with lags = 4 has  a mean squared error of 0.0707824666227016
# Model with lags = 5 has  a mean squared error of 0.07153882724528698
# Model with lags = 6 has  a mean squared error of 0.0720319954046235
# Model with lags = 7 has  a mean squared error of 0.07194167354793694
# Model with lags = 8 has  a mean squared error of 0.07249524241484814
# Model with lags = 9 has  a mean squared error of 0.0727577140817144
# Model with lags = 10 has  a mean squared error of 0.07326605713874418

# %%
errors = pd.DataFrame(errors, columns  = ['Error'])

# %%
errors.min()
# Out:
# Error    0.069144
# dtype: float64

# %% [markdown]
# The least error occurs at lags = 1

# %%
final_trainX = df_svm_scaled.iloc[:train_size, 1: 2]
final_trainY = df_svm_scaled.iloc[:train_size, 0]
final_testX = df_svm_scaled.iloc[train_size:, 1: 2]
final_testY = df_svm_scaled.iloc[train_size:, 0]

# %%
final_trainX.shape, final_trainY.shape, final_testX.shape, final_testY.shape
# Out:
# ((4160, 1), (4160,), (1041, 1), (1041,))

# %%
svmreg = SVR(kernel = 'rbf')

# %%
predictions = []
for i in range(len(final_testX)):
    svmreg.fit(final_trainX, final_trainY)
    test_svm_X = np.array(final_testX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
    test_svm_Y = final_testY.iloc[i]   # Need to reshape the test sample to the shape that the model expects
    pred = svmreg.predict(test_svm_X) # Make predictions
    final_trainX = final_trainX.append(final_testX.iloc[i])
    final_trainY.loc[len(final_trainY)] = test_svm_Y
    predictions.append(pred) # Append the prediction to the list
error =  mean_squared_error(final_testY, predictions, squared = False)

print('Error for the model is', error)
# Out:
# Error for the model is 0.06914442898344468

# %%
# Inverse Scaling the predictions

predictions = np.array(predictions)
predictions_copy = np.repeat(predictions, 11, axis = -1)
pred=svm_scaler.inverse_transform(np.reshape(predictions_copy,(len(predictions),11)))[:,0]

pred_svm = pd.DataFrame(pred, columns = ['Close'])
pred_svm = pred_svm.set_index(final_testY.index, 'Date')

# %%
# Inverse scaling the original test target values

index = final_testY.index # Saving the index, because we are converting the target values to array
final_testY = np.array(final_testY)
testY_copy = np.repeat(final_testY, 11, axis = -1)
testY = svm_scaler.inverse_transform(np.reshape(testY_copy,(len(predictions),11)))[:,0]

testY_df = pd.DataFrame(testY, columns = ['Close'])
testY_df = testY_df.set_index(index, 'Date')

# %%
# pred_lr_values = pred_lr.iloc[:, 0]

plt.plot(pred_svm, color = 'blue', label = 'Predicted Market Index')
plt.plot(testY_df, color = 'red', label = 'Real Market Index')
plt.title('Market Index Prediction using Support Vector Regressor')
plt.xlabel('Time')
plt.xticks(rotation='vertical')
plt.ylabel('Dow Jones Industrial Average')
plt.legend()
plt.show()

# %% [markdown]
# The support vector regressor is giving quite a good fit when we observe it graphically, but as far as its mean squared error of 0.069 is concerned then it is performing worse than the baseline model.

# %% [markdown]
# ### 4. XGBOOST REGRESSOR

# %%
import  xgboost

# %% [markdown]
# To be able to use a machine learning method, we need to ensure that our data is in a time series format, such that each variable has its own lagged variables that explain its current value. For simplicity we will assume that the closing price depends only on the lagged values of itself. We will use different number of lags to see which order fits the data best.

# %%
close_price = pd.DataFrame(df['Close'], columns = ['Close'])

# %%
df_xgb = close_price
for i in range (1, 11):
    str1= 'Close_l'
    str2= str1 + str(i) 
    column = close_price.rename(columns = {'Close': str2})
    lagged_df = pd.DataFrame(column.shift(+ i))
    df_xgb = pd.concat([df_xgb, lagged_df], axis = 1)
df_xgb = df_xgb.dropna()

# %%
df_xgb
# Out:
#                Close  Close_l1  Close_l2  Close_l3  Close_l4  Close_l5  \
# Date
# 2003-03-17   8141.92   7859.71   7821.75   7552.07   7524.06   7568.18
# 2003-03-18   8194.23   8141.92   7859.71   7821.75   7552.07   7524.06
# 2003-03-19   8265.45   8194.23   8141.92   7859.71   7821.75   7552.07
# 2003-03-20   8286.60   8265.45   8194.23   8141.92   7859.71   7821.75
# 2003-03-21   8521.97   8286.60   8265.45   8194.23   8141.92   7859.71
# ...              ...       ...       ...       ...       ...       ...
# 2024-04-15  37735.11  37983.24  38459.08  38461.51  38883.67  38892.80
# 2024-04-16  37798.97  37735.11  37983.24  38459.08  38461.51  38883.67
# 2024-04-17  37753.31  37798.97  37735.11  37983.24  38459.08  38461.51
# 2024-04-18  37775.38  37753.31  37798.97  37735.11  37983.24  38459.08
# 2024-04-19  37986.40  37775.38  37753.31  37798.97  37735.11  37983.24
#
#             Close_l6  Close_l7  Close_l8  Close_l9  Close_l10
# Date
# 2003-03-17   7740.03   7673.99   7775.60   7704.87    7837.86
# 2003-03-18   7568.18   7740.03   7673.99   7775.60    7704.87
# 2003-03-19   7524.06   7568.18   7740.03   7673.99    7775.60
# 2003-03-20   7552.07   7524.06   7568.18   7740.03    7673.99
# 2003-03-21   7821.75   7552.07   7524.06   7568.18    7740.03
# ...              ...       ...       ...       ...        ...
# 2024-04-15  38904.04  38596.98  39127.14  39170.24   39566.85
# 2024-04-16  38892.80  38904.04  38596.98  39127.14   39170.24
# 2024-04-17  38883.67  38892.80  38904.04  38596.98   39127.14
# 2024-04-18  38461.51  38883.67  38892.80  38904.04   38596.98
# 2024-04-19  38459.08  38461.51  38883.67  38892.80   38904.04
#
# [5201 rows x 11 columns]

# %% [markdown]
# Scaling the data

# %%
xgb_scaler = StandardScaler()

# %%
xgb_scaled = xgb_scaler.fit_transform(df_xgb)

# %%
df_xgb_scaled = pd.DataFrame(xgb_scaled, columns = df_xgb.columns, index = df_xgb.index)

# %%
df_xgb_scaled
# Out:
#                Close  Close_l1  Close_l2  Close_l3  Close_l4  Close_l5  \
# Date
# 2003-03-17 -1.178242 -1.210205 -1.214279 -1.244819 -1.247754 -1.242445
# 2003-03-18 -1.172270 -1.177977 -1.209942 -1.214002 -1.244553 -1.247490
# 2003-03-19 -1.164140 -1.172004 -1.177704 -1.209664 -1.213726 -1.244287
# 2003-03-20 -1.161725 -1.163871 -1.171728 -1.177416 -1.209387 -1.213451
# 2003-03-21 -1.134856 -1.161455 -1.163593 -1.171438 -1.177128 -1.209110
# ...              ...       ...       ...       ...       ...       ...
# 2024-04-15  2.200082  2.229821  2.285565  2.287234  2.336890  2.339344
# 2024-04-16  2.207373  2.201486  2.231207  2.286957  2.288633  2.338300
# 2024-04-17  2.202160  2.208778  2.202862  2.232582  2.288356  2.290028
# 2024-04-18  2.204680  2.203564  2.210157  2.204228  2.233963  2.289750
# 2024-04-19  2.228769  2.206084  2.204941  2.211525  2.205600  2.235341
#
#             Close_l6  Close_l7  Close_l8  Close_l9  Close_l10
# Date
# 2003-03-17 -1.222542 -1.229861 -1.218001 -1.225881  -1.210439
# 2003-03-18 -1.242199 -1.222304 -1.229632 -1.217782  -1.225674
# 2003-03-19 -1.247245 -1.241968 -1.222073 -1.229417  -1.217571
# 2003-03-20 -1.244041 -1.247016 -1.241744 -1.221855  -1.229211
# 2003-03-21 -1.213195 -1.243811 -1.246794 -1.241534  -1.221646
# ...              ...       ...       ...       ...        ...
# 2024-04-15  2.342083  2.308467  2.370666  2.377197   2.424238
# 2024-04-16  2.340797  2.343602  2.309981  2.372262   2.378804
# 2024-04-17  2.339753  2.342316  2.345129  2.311554   2.373867
# 2024-04-18  2.291465  2.341271  2.343842  2.346715   2.313135
# 2024-04-19  2.291187  2.292966  2.342797  2.345428   2.348310
#
# [5201 rows x 11 columns]

# %% [markdown]
# Let us split the data:

# %%
train_size = int((len(df_xgb)*0.8))

# %%
xgb = xgboost.XGBRegressor(n_estimators = 100)

# %%
# For making predictions:        
errors =[]
print('Results for XGBRegressor ranging from lags 1 to 10 and walk forward validation')
    
for j in range(1, 11):
    
    str_name = 'Model with lags = ' 
    model_name = str_name + str(j) # Naming the model
    sample_trainX = df_xgb_scaled.iloc[:train_size, 1: j+1] # Selecting all rows and columns with the current lag number indicated by the integer i
    sample_trainY = df_xgb_scaled.iloc[:train_size, 0] 
    sample_testX = df_xgb_scaled.iloc[train_size:, 1: j+1]
    sample_testY = df_xgb_scaled.iloc[train_size:, 0] # We could have kept sample_testy outside the loop as well because it is not changing
    # We are splitting the training data in each loop because in the next loop the training data is being appended for
    # walk forward validation. So, for every next iteration we need the refreshed dataset. Note that even though the data 
    # is being refreshed we are also increasing the lags every period
    predictions = []
    for i in range(len(sample_testX)):
        xgb.fit(sample_trainX, sample_trainY)
        test_xgb_X = np.array(sample_testX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
        test_xgb_Y = sample_testY.iloc[i]                          # Need to reshape the test sample to
                                                                    # the shape that the model expects
        pred = xgb.predict(test_xgb_X) # Make predictions
        sample_trainX = sample_trainX.append(sample_testX.iloc[i])
        sample_trainY.loc[len(sample_trainY)] = test_xgb_Y 
        predictions.append(pred) # Append the prediction to the list
    error =  mean_squared_error(sample_testY, predictions, squared = False)
    print(model_name, 'has  a mean squared error of', error) 
    errors.append(error)
# Out:
# Results for XGBRegressor ranging from lags 1 to 10 and walk forward validation
# Model with lags = 1 has  a mean squared error of 0.052052449159788405
# Model with lags = 2 has  a mean squared error of 0.053488075735217924
# Model with lags = 3 has  a mean squared error of 0.05464857929044045
# Model with lags = 4 has  a mean squared error of 0.0543570157226868
# Model with lags = 5 has  a mean squared error of 0.05433299449466972
# Model with lags = 6 has  a mean squared error of 0.053915869515962084
# Model with lags = 7 has  a mean squared error of 0.053982711885843526
# Model with lags = 8 has  a mean squared error of 0.05451661236339675
# Model with lags = 9 has  a mean squared error of 0.054798421570253227
# Model with lags = 10 has  a mean squared error of 0.05443641662807523

# %%
errors = pd.DataFrame(errors, columns  = ['Error'])

# %%
errors.min()
# Out:
# Error    0.052052
# dtype: float64

# %% [markdown]
# The least error occurs at lags = 1

# %%
final_trainX = df_xgb_scaled.iloc[:train_size, 1:2]
final_trainY = df_xgb_scaled.iloc[:train_size, 0]
final_testX = df_xgb_scaled.iloc[train_size:, 1:2]
final_testY = df_xgb_scaled.iloc[train_size:, 0]

# %%
final_trainX.shape, final_trainY.shape
# Out:
# ((4160, 1), (4160,))

# %%
xgb = xgboost.XGBRegressor(n_estimators = 250)

# %%
predictions = []
for i in range(len(final_testX)):
    xgb.fit(final_trainX, final_trainY)
    test_xgb_X = np.array(final_testX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
    test_xgb_Y = final_testY.iloc[i]   # Need to reshape the test sample to the shape that the model expects
    pred = xgb.predict(test_xgb_X) # Make predictions
    final_trainX = final_trainX.append(final_testX.iloc[i])
    final_trainY.loc[len(final_trainY)] = test_xgb_Y
    predictions.append(pred) # Append the prediction to the list
error =  mean_squared_error(final_testY, predictions, squared = False)

print('Error for the model is', error)
# Out:
# Error for the model is 0.05205244961937165

# %%
# Inverse Scaling the predictions

predictions = np.array(predictions)
predictions_copy = np.repeat(predictions, 11, axis = -1)
pred=xgb_scaler.inverse_transform(np.reshape(predictions_copy,(len(predictions),11)))[:,0]

pred_xgb = pd.DataFrame(pred, columns = ['Close'])
pred_xgb = pred_xgb.set_index(final_testY.index, 'Date')

# %%
# Inverse scaling the original test target values

index = final_testY.index # Saving the index, because we are converting the target values to array
final_testY = np.array(final_testY)
testY_copy = np.repeat(final_testY, 11, axis = -1)
testY = xgb_scaler.inverse_transform(np.reshape(testY_copy,(len(predictions),11)))[:,0]

testY_df = pd.DataFrame(testY, columns = ['Close'])
testY_df = testY_df.set_index(index, 'Date')

# %%
plt.plot(testY_df, color = 'red', label = 'Real Market Index')
plt.plot(pred_xgb, color = 'blue', label = 'Predicted Market Index')
plt.title('Market Index Prediction using XGBoost')
plt.xlabel('Time')
plt.xticks(rotation='vertical')
plt.ylabel('Dow Jones Industrial Average')
plt.legend()
plt.show()

# %% [markdown]
# So, XGBoost Regressor has done quite a good job in capturing the predictions.

# %% [markdown]
# ### 5. LSTM

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# %%
df_lstm = pd.DataFrame(df['Close'], columns = ['Close'])

# %%
train =df_lstm[:train_size]
test = df_lstm[train_size:]

# %%
train.shape, test.shape
# Out:
# ((4160, 1), (1051, 1))

# %%
scaler = StandardScaler()

# %%
scaler.fit(train)
train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)

# %% [markdown]
# Let us create data batches for our model. There is only one step before we get down to model building, which is to create batches for the time series. Our model will aim to look at the last 6 month values and then make a prediction for the seventh month.

# %%
def createXY(dataset,n_past):
    dataX = []
    dataY = []
    for i in range(n_past, len(dataset)):
            dataX.append(dataset[i - n_past:i, 0:dataset.shape[1]])
            dataY.append(dataset[i,0])
    return np.array(dataX),np.array(dataY)

trainX,trainY=createXY(train_scaled,10)
testX,testY=createXY(test_scaled,10)

# %%
trainX.shape, trainY.shape, testX.shape, testY.shape
# Out:
# ((4150, 10, 1), (4150,), (1041, 10, 1), (1041,))

# %%
keras.backend.clear_session()
np.random.seed(100)
tensorflow.random.set_seed(100)

# %%
model = keras.models.Sequential([
    keras.layers.LSTM(50, return_sequences = True, input_shape = [None, 1]),
    keras.layers.LSTM(30),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1)
])

# %%
model.compile(optimizer = 'adam', loss = 'mse')

# %%
history = model.fit(trainX, trainY, epochs = 20, validation_split = 0.2)
# Out:
# Epoch 1/20
# 104/104 [==============================] - 6s 19ms/step - loss: 0.0445 - val_loss: 0.4235
# Epoch 2/20
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0172 - val_loss: 0.3284
# Epoch 3/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0170 - val_loss: 0.3974
# Epoch 4/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0162 - val_loss: 0.2616
# Epoch 5/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0153 - val_loss: 0.2717
# Epoch 6/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0146 - val_loss: 0.2767
# Epoch 7/20
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0135 - val_loss: 0.2788
# Epoch 8/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0135 - val_loss: 0.2460
# Epoch 9/20
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0127 - val_loss: 0.2277
# Epoch 10/20
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0122 - val_loss: 0.2060
# Epoch 11/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0127 - val_loss: 0.1950
# Epoch 12/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0121 - val_loss: 0.2774
# Epoch 13/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0116 - val_loss: 0.1523
# Epoch 14/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0112 - val_loss: 0.1761
# Epoch 15/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0116 - val_loss: 0.1086
# Epoch 16/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0121 - val_loss: 0.1739
# Epoch 17/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0115 - val_loss: 0.1287
# Epoch 18/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0112 - val_loss: 0.1821
# Epoch 19/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0104 - val_loss: 0.1096
# Epoch 20/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0103 - val_loss: 0.1531

# %%
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.xlabel('Epochs')
plt.ylabel('Loss/Accuracy')
plt.show()

# %%
prediction = model.predict(testX)
# Out:
# 33/33 [==============================] - 1s 4ms/step

# %%
prediction.shape
# Out:
# (1041, 1)

# %%
pred=scaler.inverse_transform(np.reshape(prediction,(len(prediction),1)))[:,0]

# %%
pred
# Out:
# array([24529.748, 24326.598, 24148.059, ..., 27878.242, 27851.01 ,
#        27828.924], dtype=float32)

# %%
original = testY

# %%
original_vals = scaler.inverse_transform(np.reshape(original, (len(original), 1)))[:, 0]

# %%
original_vals
# Out:
# array([26703.32, 25917.41, 27090.86, ..., 37753.31, 37775.38, 37986.4 ])

# %%
error = mean_squared_error(original, prediction, squared = False)
print('The LSTM model has an error of', error)
# Out:
# The LSTM model has an error of 1.2462880363675404

# %%
plt.plot(original_vals, color = 'red', label = 'Real Market Index')
plt.plot(pred, color = 'blue', label = 'Predicted Market Index')
plt.title('Market Index Prediction')
plt.xlabel('Time')
plt.ylabel('Dow Jones Industrial Index')
plt.legend()
plt.show()

# %% [markdown]
# LSTM is also performing worse than linear regression and support vector regression. Despite roughly capturing the trend, it is performing quite worse than the baseline model with a mean squared error of 1.25

# %% [markdown]
# ### 6. GRU

# %%
keras.backend.clear_session()
np.random.seed(100)
tensorflow.random.set_seed(100)

# %%
model = keras.models.Sequential([
    keras.layers.GRU(40, return_sequences = True, input_shape = [None, 1]),
    keras.layers.GRU(30),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(1)
])

# %%
model.compile(optimizer = 'adam', loss = 'mse')

# %%
history = model.fit(trainX, trainY, epochs = 20, validation_split = 0.2)
# Out:
# Epoch 1/20
# 104/104 [==============================] - 7s 19ms/step - loss: 0.0789 - val_loss: 0.1045
# Epoch 2/20
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0246 - val_loss: 0.0776
# Epoch 3/20
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0222 - val_loss: 0.1114
# Epoch 4/20
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0215 - val_loss: 0.1010
# Epoch 5/20
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0201 - val_loss: 0.1447
# Epoch 6/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0186 - val_loss: 0.1338
# Epoch 7/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0174 - val_loss: 0.1637
# Epoch 8/20
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0173 - val_loss: 0.1156
# Epoch 9/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0165 - val_loss: 0.1131
# Epoch 10/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0153 - val_loss: 0.1369
# Epoch 11/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0154 - val_loss: 0.0937
# Epoch 12/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0153 - val_loss: 0.1713
# Epoch 13/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0149 - val_loss: 0.1146
# Epoch 14/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0149 - val_loss: 0.1040
# Epoch 15/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0145 - val_loss: 0.0996
# Epoch 16/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0154 - val_loss: 0.1192
# Epoch 17/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0151 - val_loss: 0.0554
# Epoch 18/20
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0153 - val_loss: 0.0848
# Epoch 19/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0144 - val_loss: 0.0858
# Epoch 20/20
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0136 - val_loss: 0.1015

# %%
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.xlabel('Epochs')
plt.ylabel('Loss/Accuracy')
plt.show()

# %%
prediction = model.predict(testX)
# Out:
# 33/33 [==============================] - 1s 3ms/step

# %%
prediction.shape
# Out:
# (1041, 1)

# %%
pred=scaler.inverse_transform(np.reshape(prediction,(len(prediction),1)))[:,0]

# %%
pred
# Out:
# array([24585.629, 24464.736, 24349.16 , ..., 30143.375, 30099.6  ,
#        30066.832], dtype=float32)

# %%
original = testY

# %%
original_vals = scaler.inverse_transform(np.reshape(original, (len(original), 1)))[:, 0]

# %%
original_vals
# Out:
# array([26703.32, 25917.41, 27090.86, ..., 37753.31, 37775.38, 37986.4 ])

# %%
error = mean_squared_error(original, prediction, squared = False)
print('The GRU model has an error of', error)
# Out:
# The GRU model has an error of 0.9538312469231193

# %%
plt.plot(original_vals, color = 'red', label = 'Real Market Index')
plt.plot(pred, color = 'blue', label = 'Predicted Market Index')
plt.title('Market Index Prediction')
plt.xlabel('Time')
plt.ylabel('Dow Jones Industrial Index')
plt.legend()
plt.show()

# %% [markdown]
# Finally, GRU stands as the best model after linear regression, which outperforms LSTM, XGBoost Regressor and Support Vector Regressor with an MSE of 0.95. This MSE is not great after all since the baseline model is significantly better than GRU but inspite of that the algorithm has been able to roughly capture the trend of the data.

# %% [markdown]
# Therefore, we shortlist:
# 1. Linear Regression
# 2. XGBRegressor;
#
# for the fine tuning stage. The target would be to outperform the baseline model's MSE of 0.043.

# %% [markdown]
# # HYPERPARAMETER TUNING

# %% [markdown]
# ## 1. LINEAR REGRESSION

# %% [markdown]
# This time we will split our data in training-validation-test such that the subsets have 60%, 20% and 20% data

# %%
close_price = pd.DataFrame(df['Close'], columns = ['Close'])

# %%
df_lr = close_price
for i in range (1, 3):
    str1= 'Close_l'
    str2= str1 + str(i) 
    column = close_price.rename(columns = {'Close': str2})
    lagged_df = pd.DataFrame(column.shift(+ i))
    df_lr = pd.concat([df_lr, lagged_df], axis = 1)
df_lr = df_lr.dropna()

# %%
df_lr
# Out:
#                Close  Close_l1  Close_l2
# Date
# 2003-03-05   7775.60   7704.87   7837.86
# 2003-03-06   7673.99   7775.60   7704.87
# 2003-03-07   7740.03   7673.99   7775.60
# 2003-03-10   7568.18   7740.03   7673.99
# 2003-03-11   7524.06   7568.18   7740.03
# ...              ...       ...       ...
# 2024-04-15  37735.11  37983.24  38459.08
# 2024-04-16  37798.97  37735.11  37983.24
# 2024-04-17  37753.31  37798.97  37735.11
# 2024-04-18  37775.38  37753.31  37798.97
# 2024-04-19  37986.40  37775.38  37753.31
#
# [5209 rows x 3 columns]

# %%
lr_scaler = StandardScaler()

lr_scaled = lr_scaler.fit_transform(df_lr)

df_lr_scaled = pd.DataFrame(lr_scaled, columns = df_lr.columns, index = df_lr.index)

df_lr_scaled
# Out:
#                Close  Close_l1  Close_l2
# Date
# 2003-03-05 -1.217694 -1.225511 -1.210069
# 2003-03-06 -1.229289 -1.217437 -1.225256
# 2003-03-07 -1.221753 -1.229036 -1.217179
# 2003-03-10 -1.241364 -1.221497 -1.228782
# 2003-03-11 -1.246399 -1.241114 -1.221241
# ...              ...       ...       ...
# 2024-04-15  2.201109  2.230831  2.286553
# 2024-04-16  2.208396  2.202506  2.232217
# 2024-04-17  2.203185  2.209796  2.203883
# 2024-04-18  2.205704  2.204584  2.211175
# 2024-04-19  2.229784  2.207103  2.205962
#
# [5209 rows x 3 columns]

# %%
training_size = int(len(df_lr_scaled)*0.60)
print(training_size)
# Out:
# 3125

# %%
validation_size = int(len(df_lr_scaled)*0.80)
validation_size
# Out:
# 4167

# %%
trainX, trainY = df_lr_scaled.iloc[:training_size, 1:], df_lr_scaled.iloc[:training_size, 0]
validX, validY = df_lr_scaled.iloc[training_size:validation_size, 1:], df_lr_scaled.iloc[training_size:validation_size, 0]
testX, testY = df_lr_scaled.iloc[validation_size:,  1:], df_lr_scaled.iloc[validation_size:, 0]

# %%
trainX.shape, trainY.shape, validX.shape, validY.shape, testX.shape, testY.shape
# Out:
# ((3125, 2), (3125,), (1042, 2), (1042,), (1042, 2), (1042,))

# %% [markdown]
# Let us use a Ridge regression to apply some regularization.

# %%
from sklearn.linear_model import Ridge

# %%
alphas  = [0.0001, 0.001, 0.01, 0.1, 1, 10]
solvers = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
models = []
for i in range(len(alphas)):
    for j in range(len(solvers)):
        if solvers[j] == 'lbfgs':
            model = Ridge(alpha = alphas[i], solver = solvers[j], positive = True)
        else:
            model = Ridge(alpha = alphas[i], solver = solvers[j])
        models.append(model)

# %%
errors = []
for model in models:
    predictions = []
    for i in range(len(validX)):
        model.fit(trainX, trainY)
        valid_ridge_X = np.array(validX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
        valid_ridge_Y = validY.iloc[i]   # Need to reshape the test sample to the shape that the model expects
        pred = model.predict(valid_ridge_X) # Make predictions
        trainX = trainX.append(validX.iloc[i])
        trainY.loc[len(trainY)] = valid_ridge_Y
        predictions.append(pred) # Append the prediction to the list
    error =  mean_squared_error(validY, predictions, squared = False)
    errors.append(error) 
    print('Error for the model', model, 'is', error)
# Out:
# Error for the model Ridge(alpha=0.0001) is 0.07152439444618643
# Error for the model Ridge(alpha=0.0001, solver='svd') is 0.07117685433929552
# Error for the model Ridge(alpha=0.0001, solver='cholesky') is 0.07115270149569473
# Error for the model Ridge(alpha=0.0001, solver='lsqr') is 0.07113609244349169
# Error for the model Ridge(alpha=0.0001, solver='sparse_cg') is 0.07112219986179752
# Error for the model Ridge(alpha=0.0001, solver='sag') is 0.07111050408884934
# Error for the model Ridge(alpha=0.0001, solver='saga') is 0.07110097960167139
# Error for the model Ridge(alpha=0.0001, positive=True, solver='lbfgs') is 0.0710889315943844
# Error for the model Ridge(alpha=0.001) is 0.07107976752381756
# Error for the model Ridge(alpha=0.001, solver='svd') is 0.0710713375284752
# Error for the model Ridge(alpha=0.001, solver='cholesky') is 0.07106355717551126
# Error for the model Ridge(alpha=0.001, solver='lsqr') is 0.0710563551581053
# Error for the model Ridge(alpha=0.001, solver='sparse_cg') is 0.07104967156129234
# Error for the model Ridge(alpha=0.001, solver='sag') is 0.07104195974238275
# Error for the model Ridge(alpha=0.001, solver='saga') is 0.07103663210001396
# Error for the model Ridge(alpha=0.001, positive=True, solver='lbfgs') is 0.07103224362670393
# Error for the model Ridge(alpha=0.01) is 0.0710271865862435
# Error for the model Ridge(alpha=0.01, solver='svd') is 0.07102244596890525
# Error for the model Ridge(alpha=0.01, solver='cholesky') is 0.07101799804469879
# Error for the model Ridge(alpha=0.01, solver='lsqr') is 0.07101381873760591
# Error for the model Ridge(alpha=0.01, solver='sparse_cg') is 0.07100988646767757
# Error for the model Ridge(alpha=0.01, solver='sag') is 0.07100561447191683
# Error for the model Ridge(alpha=0.01, solver='saga') is 0.07100319491706679
# Error for the model Ridge(alpha=0.01, positive=True, solver='lbfgs') is 0.07099936986715387
# Error for the model Ridge(alpha=0.1) is 0.07099622742220627
# Error for the model Ridge(alpha=0.1, solver='svd') is 0.07099327361900765
# Error for the model Ridge(alpha=0.1, solver='cholesky') is 0.07099047518896268
# Error for the model Ridge(alpha=0.1, solver='lsqr') is 0.07098782128073024
# Error for the model Ridge(alpha=0.1, solver='sparse_cg') is 0.07098530198623662
# Error for the model Ridge(alpha=0.1, solver='sag') is 0.07097938186821467
# Error for the model Ridge(alpha=0.1, solver='saga') is 0.07098028749263764
# Error for the model Ridge(alpha=0.1, positive=True, solver='lbfgs') is 0.070978439387949
# Error for the model Ridge(alpha=1) is 0.07097700395913281
# Error for the model Ridge(alpha=1, solver='svd') is 0.07097498279707645
# Error for the model Ridge(alpha=1, solver='cholesky') is 0.07097305716934091
# Error for the model Ridge(alpha=1, solver='lsqr') is 0.070971220950099
# Error for the model Ridge(alpha=1, solver='sparse_cg') is 0.07096946851670254
# Error for the model Ridge(alpha=1, solver='sag') is 0.07096155719732354
# Error for the model Ridge(alpha=1, solver='saga') is 0.07096565439654583
# Error for the model Ridge(alpha=1, positive=True, solver='lbfgs') is 0.07096463294462974
# Error for the model Ridge(alpha=10) is 0.07102004979891381
# Error for the model Ridge(alpha=10, solver='svd') is 0.0710160834822833
# Error for the model Ridge(alpha=10, solver='cholesky') is 0.07101234280589744
# Error for the model Ridge(alpha=10, solver='lsqr') is 0.07100881034455175
# Error for the model Ridge(alpha=10, solver='sparse_cg') is 0.07100547036485523
# Error for the model Ridge(alpha=10, solver='sag') is 0.07100362487053037
# Error for the model Ridge(alpha=10, solver='saga') is 0.07099979010754179
# Error for the model Ridge(alpha=10, positive=True, solver='lbfgs') is 0.07099646770697227

# %%
errors_df = pd.DataFrame(errors, columns = ['Errors'])

# %%
a = errors_df.min()
errors_df[errors_df == a]
# Out:
#       Errors
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       NaN
# 33       NaN
# 34       NaN
# 35       NaN
# 36       NaN
# 37  0.070962
# 38       NaN
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46       NaN
# 47       NaN

# %%
models[37]
# Out:
# Ridge(alpha=1, solver='sag')

# %% [markdown]
# Thus, this is the best model. Running this model on the data gives an MSE of 0.0427, as can be seen below:

# %%
train_size = int(len(df_lr_scaled)*0.80)
final_trainX = df_lr_scaled.iloc[:train_size, 1: 3]
final_trainY = df_lr_scaled.iloc[:train_size, 0]
final_testX = df_lr_scaled.iloc[train_size:, 1: 3]
final_testY = df_lr_scaled.iloc[train_size:, 0]

# %%
final_trainX.shape, final_testY.shape
# Out:
# ((4167, 2), (1042,))

# %%
final_model = Ridge(alpha = 1, solver = 'sag')

# %%
predictions = []
for i in range(len(final_testX)):
    final_model.fit(final_trainX, final_trainY)
    test_ridge_X = np.array(final_testX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
    test_ridge_Y = final_testY.iloc[i]   # Need to reshape the test sample to the shape that the model expects
    pred = final_model.predict(test_ridge_X) # Make predictions
    final_trainX = final_trainX.append(final_testX.iloc[i])
    final_trainY.loc[len(final_trainY)] = test_ridge_Y 
    predictions.append(pred) # Append the prediction to the list
    
error =  mean_squared_error(final_testY, predictions, squared = False)
print('Error for the model is', error)
# Out:
# Error for the model is 0.04273464446150733

# %% [markdown]
# ## 2. XGB Regressor

# %%
close_price = pd.DataFrame(df['Close'], columns = ['Close'])

df_xgb = close_price
for i in range (1, 2):
    str1= 'Close_l'
    str2= str1 + str(i) 
    column = close_price.rename(columns = {'Close': str2})
    lagged_df = pd.DataFrame(column.shift(+ i))
    df_xgb = pd.concat([df_xgb, lagged_df], axis = 1)
df_xgb = df_xgb.dropna()

# %%
df_xgb
# Out:
#                Close  Close_l1
# Date
# 2003-03-04   7704.87   7837.86
# 2003-03-05   7775.60   7704.87
# 2003-03-06   7673.99   7775.60
# 2003-03-07   7740.03   7673.99
# 2003-03-10   7568.18   7740.03
# ...              ...       ...
# 2024-04-15  37735.11  37983.24
# 2024-04-16  37798.97  37735.11
# 2024-04-17  37753.31  37798.97
# 2024-04-18  37775.38  37753.31
# 2024-04-19  37986.40  37775.38
#
# [5210 rows x 2 columns]

# %%
xgb_scaler = StandardScaler()

# %%
xgb_scaled = xgb_scaler.fit_transform(df_xgb)

# %%
df_xgb_scaled = pd.DataFrame(xgb_scaled, columns = df_xgb.columns, index = df_xgb.index)

# %%
df_xgb_scaled
# Out:
#                Close  Close_l1
# Date
# 2003-03-04 -1.225471 -1.210043
# 2003-03-05 -1.217400 -1.225224
# 2003-03-06 -1.228995 -1.217150
# 2003-03-07 -1.221459 -1.228749
# 2003-03-10 -1.241069 -1.221210
# ...              ...       ...
# 2024-04-15  2.201238  2.230963
# 2024-04-16  2.208525  2.202640
# 2024-04-17  2.203315  2.209930
# 2024-04-18  2.205833  2.204718
# 2024-04-19  2.229912  2.207237
#
# [5210 rows x 2 columns]

# %%
train_size = int(len(df_xgb_scaled) * 0.80)

trainX = df_xgb_scaled.iloc[:train_size, 1:2]
trainY = df_xgb_scaled.iloc[:train_size, 0]
testX = df_xgb_scaled.iloc[train_size:, 1:2]
testY = df_xgb_scaled.iloc[train_size:, 0]

# %%
n_estimators = [150, 200, 250, 300]
learning_rate = [0.001, 0.01, 0.1, 1]

for estimator in n_estimators:
    for rate in learning_rate:
        xgb = xgboost.XGBRegressor(n_estimators = estimator, learning_rate = rate)
        predictions = []
        for i in range(len(testX)):
            xgb_fitted = xgb.fit(trainX, trainY)
            test_xgb_X = np.array(testX.iloc[i]).reshape(1, -1) # Pick up one single row with ith index 
            test_xgb_Y = testY.iloc[i]   # Need to reshape the test sample to the shape that the model expects
            pred = xgb_fitted.predict(test_xgb_X) # Make predictions
            trainX = trainX.append(testX.iloc[i])
            trainY.loc[len(trainY)] = test_xgb_Y
            predictions.append(pred) # Append the prediction to the list
        error =  mean_squared_error(testY, predictions, squared = False)
        print('Error for the model with estimators equal to', estimator, 'and learning rate equal to', rate, 'is', error)
# Out:
# Error for the model with estimators equal to 150 and learning rate equal to 0.001 is 0.9090749597494243
# Error for the model with estimators equal to 150 and learning rate equal to 0.01 is 0.218750984966146
# Error for the model with estimators equal to 150 and learning rate equal to 0.1 is 0.03976930441953219
# Error for the model with estimators equal to 150 and learning rate equal to 1 is 0.040340536921420686
# Error for the model with estimators equal to 200 and learning rate equal to 0.001 is 0.6434314617086944
# Error for the model with estimators equal to 200 and learning rate equal to 0.01 is 0.1081710850358363
# Error for the model with estimators equal to 200 and learning rate equal to 0.1 is 0.03929322006577691
# Error for the model with estimators equal to 200 and learning rate equal to 1 is 0.038828968815353165
# Error for the model with estimators equal to 250 and learning rate equal to 0.001 is 0.5134016429584528
# Error for the model with estimators equal to 250 and learning rate equal to 0.01 is 0.06500706766462924
# Error for the model with estimators equal to 250 and learning rate equal to 0.1 is 0.0391858474393153
# Error for the model with estimators equal to 250 and learning rate equal to 1 is 0.039401026607412064
# Error for the model with estimators equal to 300 and learning rate equal to 0.001 is 0.4367583885013476
# Error for the model with estimators equal to 300 and learning rate equal to 0.01 is 0.04900196359557731
# Error for the model with estimators equal to 300 and learning rate equal to 0.1 is 0.03938620041522757
# Error for the model with estimators equal to 300 and learning rate equal to 1 is 0.039013356818760496

# %% [markdown]
# Thus, the model with 200 estimators and learning rate equal to 1 has the least MSE of 0.0388, which beats our baseline model. But given the stochastic nature of the algorithm, we may as well use models with:
# 1. Estimators = 150 and learning rate = 0.1
# 2. Estimators = 150 and learning rate = 1
# 3. Estimators = 200 and learning rate = 0.1
# 4. Estimators = 250 and learning rate = 0.1
# 5. Estimators = 250 and learning rate = 1
# 6. Estimators = 300 and learning rate = 0.1
# 7. Estimators = 300 and learning rate = 1
#
# All of these models beat the baseline model.

# %% [markdown]
# ## 3. ARIMA

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
df_arima = pd.DataFrame(df['Close'], columns = ['Close'])

# %%
df_arima
# Out:
#                Close
# Date
# 2003-03-03   7837.86
# 2003-03-04   7704.87
# 2003-03-05   7775.60
# 2003-03-06   7673.99
# 2003-03-07   7740.03
# ...              ...
# 2024-04-15  37735.11
# 2024-04-16  37798.97
# 2024-04-17  37753.31
# 2024-04-18  37775.38
# 2024-04-19  37986.40
#
# [5211 rows x 1 columns]

# %%
# For ARIMA we will use all p and q values between 0 and 10
p_range = range(0, 11)
q_range = range(0, 11)

# Disable stepwise search and set information criterion 

AIC = []
P = []
Q = []
for p in p_range:
    for q in q_range:
    # Fit the ARIMA model for current p and q values
        model = ARIMA(df_arima, order = (p, 1, q))
        model_fit = model.fit()
        aic = model_fit.aic
        P.append(p)
        Q.append(q)
        AIC.append(aic)
        print('For p =', p, 'and q =', q,'AIC = ', aic)
aic_df = pd.DataFrame(AIC, P, Q, columns = ['AIC', 'P', 'Q'])
# Out:
# For p = 0 and q = 0 AIC =  75533.12032927302
# For p = 0 and q = 1 AIC =  75500.1157584973
# For p = 0 and q = 2 AIC =  75046.9707997469
# For p = 0 and q = 3 AIC =  75046.62824406642
# For p = 0 and q = 4 AIC =  75038.5586542574
# For p = 0 and q = 5 AIC =  75027.26503497596
# For p = 0 and q = 6 AIC =  75019.13649478924
# For p = 0 and q = 7 AIC =  75003.66943361239
# For p = 0 and q = 8 AIC =  74998.21035533959
# For p = 0 and q = 9 AIC =  74988.10264627548
# For p = 0 and q = 10 AIC =  74989.48268815034
# For p = 1 and q = 0 AIC =  75519.17085019007
# For p = 1 and q = 1 AIC =  75279.34417533773
# For p = 1 and q = 2 AIC =  75045.45723574542
# For p = 1 and q = 3 AIC =  75002.68167523234
# For p = 1 and q = 4 AIC =  74998.78845787072
# For p = 1 and q = 5 AIC =  74997.9215683779
# For p = 1 and q = 6 AIC =  74996.61676694662
# For p = 1 and q = 7 AIC =  74992.59400631243
# For p = 1 and q = 8 AIC =  74993.21589090175
# For p = 1 and q = 9 AIC =  74989.75490809935
# For p = 1 and q = 10 AIC =  74992.10652553392
# For p = 2 and q = 0 AIC =  75119.11187064173
# For p = 2 and q = 1 AIC =  75102.21327491527
# For p = 2 and q = 2 AIC =  75015.85225013521
# For p = 2 and q = 3 AIC =  75000.02850606863
# For p = 2 and q = 4 AIC =  74983.89705323476
# For p = 2 and q = 5 AIC =  74983.08993772203
# For p = 2 and q = 6 AIC =  74982.63556604978
# For p = 2 and q = 7 AIC =  74983.47650090759
# For p = 2 and q = 8 AIC =  74985.42616155784
# For p = 2 and q = 9 AIC =  74989.89440264928
# For p = 2 and q = 10 AIC =  74987.38432375275
# For p = 3 and q = 0 AIC =  75114.898374438
# For p = 3 and q = 1 AIC =  75082.07394171538
# For p = 3 and q = 2 AIC =  74998.92610731645
# For p = 3 and q = 3 AIC =  75000.32912596899
# For p = 3 and q = 4 AIC =  75002.54175888389
# For p = 3 and q = 5 AIC =  74983.3824132355
# For p = 3 and q = 6 AIC =  74986.80528970406
# For p = 3 and q = 7 AIC =  74985.09111646035
# For p = 3 and q = 8 AIC =  74987.09940090743
# For p = 3 and q = 9 AIC =  74989.00588343455
# For p = 3 and q = 10 AIC =  74989.25382663767
# For p = 4 and q = 0 AIC =  75064.34680084107
# For p = 4 and q = 1 AIC =  75064.83152352578
# For p = 4 and q = 2 AIC =  75000.35348392627
# For p = 4 and q = 3 AIC =  75002.43922867207
# For p = 4 and q = 4 AIC =  75004.11428065886
# For p = 4 and q = 5 AIC =  74984.68716745303
# For p = 4 and q = 6 AIC =  74989.16531599454
# For p = 4 and q = 7 AIC =  74987.24029766943
# For p = 4 and q = 8 AIC =  74989.01823328737
# For p = 4 and q = 9 AIC =  74988.92107132239
# For p = 4 and q = 10 AIC =  74989.78027081094
# For p = 5 and q = 0 AIC =  75066.24727656425
# For p = 5 and q = 1 AIC =  75063.96815106619
# For p = 5 and q = 2 AIC =  75002.26958682068
# For p = 5 and q = 3 AIC =  75003.20465044086
# For p = 5 and q = 4 AIC =  75005.03481109394
# For p = 5 and q = 5 AIC =  74985.66436274821
# For p = 5 and q = 6 AIC =  74986.61098991036
# For p = 5 and q = 7 AIC =  74988.02688189672
# For p = 5 and q = 8 AIC =  74989.28280053943
# For p = 5 and q = 9 AIC =  74990.15928507116
# For p = 5 and q = 10 AIC =  74991.81692534119
# For p = 6 and q = 0 AIC =  75048.89633255581
# For p = 6 and q = 1 AIC =  74994.19824902301
# For p = 6 and q = 2 AIC =  74989.33186617722
# For p = 6 and q = 3 AIC =  75001.90665696097
# For p = 6 and q = 4 AIC =  75000.82672693377
# For p = 6 and q = 5 AIC =  74986.80886184197
# For p = 6 and q = 6 AIC =  74988.45217667037
# For p = 6 and q = 7 AIC =  74989.58771267434
# For p = 6 and q = 8 AIC =  74989.9003617322
# For p = 6 and q = 9 AIC =  74991.87439422228
# For p = 6 and q = 10 AIC =  74993.59652484342
# For p = 7 and q = 0 AIC =  75045.80174629597
# For p = 7 and q = 1 AIC =  74995.5630389702
# For p = 7 and q = 2 AIC =  74997.97590676296
# For p = 7 and q = 3 AIC =  74988.78424454754
# For p = 7 and q = 4 AIC =  74990.76988859577
# For p = 7 and q = 5 AIC =  74989.3575112508
# For p = 7 and q = 6 AIC =  74990.45310620488
# For p = 7 and q = 7 AIC =  74992.0469425266
# For p = 7 and q = 8 AIC =  74990.51814552449
# For p = 7 and q = 9 AIC =  74993.79530474446
# For p = 7 and q = 10 AIC =  74995.95063997596
# For p = 8 and q = 0 AIC =  75025.41185964912
# For p = 8 and q = 1 AIC =  74985.83558329954
# For p = 8 and q = 2 AIC =  74984.18338195194
# For p = 8 and q = 3 AIC =  74985.89962579033
# For p = 8 and q = 4 AIC =  74990.59773082404
# For p = 8 and q = 5 AIC =  74989.2899197849
# For p = 8 and q = 6 AIC =  74990.00602920781
# For p = 8 and q = 7 AIC =  74991.63365106635
# For p = 8 and q = 8 AIC =  74993.71297608943
# For p = 8 and q = 9 AIC =  74995.80252062171
# For p = 8 and q = 10 AIC =  74996.01888725247
# For p = 9 and q = 0 AIC =  74996.87773830621
# For p = 9 and q = 1 AIC =  74983.74937383352
# For p = 9 and q = 2 AIC =  74985.71952047535
# For p = 9 and q = 3 AIC =  74987.3731828508
# For p = 9 and q = 4 AIC =  74988.92803992717
# For p = 9 and q = 5 AIC =  74989.486566795
# For p = 9 and q = 6 AIC =  74992.48116642058
# For p = 9 and q = 7 AIC =  74993.62811077392
# For p = 9 and q = 8 AIC =  74995.6939311538
# For p = 9 and q = 9 AIC =  74997.8276705136
# For p = 9 and q = 10 AIC =  74999.7923120037
# For p = 10 and q = 0 AIC =  74990.82629544771
# For p = 10 and q = 1 AIC =  74985.71632711668
# For p = 10 and q = 2 AIC =  74987.63087865546
# For p = 10 and q = 3 AIC =  74989.76513091839
# For p = 10 and q = 4 AIC =  74990.72268927081
# For p = 10 and q = 5 AIC =  75000.08878563473
# For p = 10 and q = 6 AIC =  74994.26272315855
# For p = 10 and q = 7 AIC =  74994.35447659637
# For p = 10 and q = 8 AIC =  74994.26318727262
# For p = 10 and q = 9 AIC =  74999.73347508354
# For p = 10 and q = 10 AIC =  75001.64860630804
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11000\1523059493.py in <module>
#      17         AIC.append(aic)
#      18         print('For p =', p, 'and q =', q,'AIC = ', aic)
# ---> 19 aic_df = pd.DataFrame(AIC, P, Q, columns = ['AIC', 'P', 'Q'])
#
# TypeError: __init__() got multiple values for argument 'columns'

# %%
aic_df = pd.DataFrame({'P':P, 'Q':Q, 'AIC':AIC})
aic_df.sort_values(by = ['AIC'])[:10]
# Out:
#      P  Q           AIC
# 28   2  6  74982.635566
# 27   2  5  74983.089938
# 38   3  5  74983.382413
# 29   2  7  74983.476501
# 100  9  1  74983.749374
# 26   2  4  74983.897053
# 90   8  2  74984.183382
# 49   4  5  74984.687167
# 40   3  7  74985.091116
# 30   2  8  74985.426162

# %% [markdown]
# Clearly, ARIMA with order (2, 1, 6) has the minimum AIC score.

# %%
# Make predictions using walk forward validation
predictions = []
for i in range(len(test)):
    arima_model = ARIMA(train['Close'], order = (2, 1, 6))
    arima_fit = arima_model.fit()
    start = len(train)
    end = start + 1
    pred_arima = np.array(arima_fit.predict(start = start, end = end).iloc[-1]) 
    # np.array because arima outputs a pandas series 
    # For ARIMA, the model predicts the future value by simply using the values from the past, so we do not need to
    # supply 'x' and 'y' like we do in any other machine learning model
    train = train.append(test.iloc[i])
    predictions.append(pred_arima) # Append the prediction to the list
    print('iteration', i, 'and prediction =', pred_arima)
error =  mean_squared_error(test, predictions, squared = False)

print('Error for the model is', error)
# Out:
# iteration 0 and prediction = 26283.710459499216
# iteration 1 and prediction = 26366.259194496655
# iteration 2 and prediction = 25873.451245319193
# iteration 3 and prediction = 26481.624103267553
# iteration 4 and prediction = 25980.16417490382
# iteration 5 and prediction = 26707.816236888924
# iteration 6 and prediction = 26096.46367218166
# iteration 7 and prediction = 26296.05631770975
# iteration 8 and prediction = 25057.00900334234
# iteration 9 and prediction = 25618.391657812237
# iteration 10 and prediction = 24396.15700589526
# iteration 11 and prediction = 23444.1586626721
# iteration 12 and prediction = 23712.181263367125
# iteration 13 and prediction = 21906.412883399524
# iteration 14 and prediction = 22261.42706248504
# iteration 15 and prediction = 20818.425959891283
# iteration 16 and prediction = 20930.12696665559
# iteration 17 and prediction = 19980.828055541824
# iteration 18 and prediction = 19499.741548225236
# iteration 19 and prediction = 20278.500167870505
# iteration 20 and prediction = 20467.298049818364
# iteration 21 and prediction = 21518.220967283505
# iteration 22 and prediction = 21250.785953984556
# iteration 23 and prediction = 21811.568801650974
# iteration 24 and prediction = 21706.42390459272
# iteration 25 and prediction = 21294.253443222453
# iteration 26 and prediction = 21517.10402965622
# iteration 27 and prediction = 21186.85984569219
# iteration 28 and prediction = 22032.463593786208
# iteration 29 and prediction = 22116.332343722865
# iteration 30 and prediction = 22698.024488775234
# iteration 31 and prediction = 23056.67956661385
# iteration 32 and prediction = 23037.672272261407
# iteration 33 and prediction = 23512.814286497938
# iteration 34 and prediction = 23334.00221185529
# iteration 35 and prediction = 23455.780607743673
# iteration 36 and prediction = 23856.04824314431
# iteration 37 and prediction = 23562.337230237878
# iteration 38 and prediction = 23412.72271258888
# iteration 39 and prediction = 23568.117852714717
# iteration 40 and prediction = 23462.10522632578
# iteration 41 and prediction = 23699.766661515747
# iteration 42 and prediction = 23827.88259525728
# iteration 43 and prediction = 23913.87307620705
# iteration 44 and prediction = 24268.284989504682
# iteration 45 and prediction = 24164.793643324516
# iteration 46 and prediction = 23971.129253984705
# iteration 47 and prediction = 23920.680579852993
# iteration 48 and prediction = 23895.18155980308
# iteration 49 and prediction = 23809.82697550551
# iteration 50 and prediction = 23875.770772404387
# iteration 51 and prediction = 24081.882157870332
# iteration 52 and prediction = 24093.32520292574
# iteration 53 and prediction = 23919.30167787872
# iteration 54 and prediction = 23628.220762107663
# iteration 55 and prediction = 23716.51500688625
# iteration 56 and prediction = 23680.331319871413
# iteration 57 and prediction = 24171.244914651517
# iteration 58 and prediction = 24033.781880672053
# iteration 59 and prediction = 24342.362011541503
# iteration 60 and prediction = 24307.692540431675
# iteration 61 and prediction = 24371.942056371598
# iteration 62 and prediction = 24682.106342245956
# iteration 63 and prediction = 25006.232812846025
# iteration 64 and prediction = 25094.45569006848
# iteration 65 and prediction = 25216.814991269086
# iteration 66 and prediction = 25273.75731750248
# iteration 67 and prediction = 25498.106891736006
# iteration 68 and prediction = 25814.146236107183
# iteration 69 and prediction = 25944.716659887297
# iteration 70 and prediction = 26501.547682989054
# iteration 71 and prediction = 26865.021282200138
# iteration 72 and prediction = 26942.19470234274
# iteration 73 and prediction = 26941.295050406858
# iteration 74 and prediction = 25960.283881340616
# iteration 75 and prediction = 26097.31324913657
# iteration 76 and prediction = 25898.17794268767
# iteration 77 and prediction = 26166.301644153373
# iteration 78 and prediction = 26106.040209692765
# iteration 79 and prediction = 26078.88601652163
# iteration 80 and prediction = 25994.518972747337
# iteration 81 and prediction = 26034.871141159416
# iteration 82 and prediction = 26076.670603616963
# iteration 83 and prediction = 25753.645609182342
# iteration 84 and prediction = 25843.05014476591
# iteration 85 and prediction = 25398.813395430636
# iteration 86 and prediction = 25640.321576912156
# iteration 87 and prediction = 25679.913082998515
# iteration 88 and prediction = 25676.057468311956
# iteration 89 and prediction = 25780.60077028454
# iteration 90 and prediction = 25988.79906359287
# iteration 91 and prediction = 25865.23197510522
# iteration 92 and prediction = 26017.47726581534
# iteration 93 and prediction = 25787.209230270266
# iteration 94 and prediction = 26015.263227751042
# iteration 95 and prediction = 25981.577640949316
# iteration 96 and prediction = 26325.967943292595
# iteration 97 and prediction = 26504.355485308664
# iteration 98 and prediction = 26545.02162303187
# iteration 99 and prediction = 26593.095338125142
# iteration 100 and prediction = 26610.19504415248
# iteration 101 and prediction = 26711.870237540807
# iteration 102 and prediction = 26840.871692691337
# iteration 103 and prediction = 26684.6028679071
# iteration 104 and prediction = 26629.784265571707
# iteration 105 and prediction = 26617.786977968062
# iteration 106 and prediction = 26497.25938773294
# iteration 107 and prediction = 26570.306314801222
# iteration 108 and prediction = 26412.487858538458
# iteration 109 and prediction = 26472.90321218569
# iteration 110 and prediction = 26563.02885346085
# iteration 111 and prediction = 26662.072753043612
# iteration 112 and prediction = 26919.067703782745
# iteration 113 and prediction = 27067.4505069309
# iteration 114 and prediction = 27197.966771342322
# iteration 115 and prediction = 27460.63309303605
# iteration 116 and prediction = 27471.81329098926
# iteration 117 and prediction = 27727.812115140525
# iteration 118 and prediction = 27722.586746183944
# iteration 119 and prediction = 27817.48316799514
# iteration 120 and prediction = 27804.15840925171
# iteration 121 and prediction = 27778.93195632635
# iteration 122 and prediction = 27746.28116726378
# iteration 123 and prediction = 27751.560192060835
# iteration 124 and prediction = 27841.695593873188
# iteration 125 and prediction = 28061.988903890197
# iteration 126 and prediction = 28079.862433739232
# iteration 127 and prediction = 28204.40790436351
# iteration 128 and prediction = 28305.265646659318
# iteration 129 and prediction = 28444.86185608328
# iteration 130 and prediction = 28390.286203675863
# iteration 131 and prediction = 28532.997672963695
# iteration 132 and prediction = 28779.266774429965
# iteration 133 and prediction = 28437.408678604475
# iteration 134 and prediction = 28389.26281542546
# iteration 135 and prediction = 27937.24407302311
# iteration 136 and prediction = 28082.369608888563
# iteration 137 and prediction = 27780.273054299138
# iteration 138 and prediction = 27811.948010504522
# iteration 139 and prediction = 27924.673083549686
# iteration 140 and prediction = 27913.782206274034
# iteration 141 and prediction = 27990.672071698922
# iteration 142 and prediction = 27918.943101547786
# iteration 143 and prediction = 27789.065333220173
# iteration 144 and prediction = 27511.698311463722
# iteration 145 and prediction = 27475.63697940899
# iteration 146 and prediction = 27130.520992208516
# iteration 147 and prediction = 27084.702033169233
# iteration 148 and prediction = 27165.895111244976
# iteration 149 and prediction = 27360.415867366683
# iteration 150 and prediction = 27359.75946469338
# iteration 151 and prediction = 27574.485269680663
# iteration 152 and prediction = 27621.82422059958
# iteration 153 and prediction = 27630.890651550388
# iteration 154 and prediction = 27896.233502062456
# iteration 155 and prediction = 27733.31182366622
# iteration 156 and prediction = 28081.034764992408
# iteration 157 and prediction = 28150.936803729182
# iteration 158 and prediction = 28333.913208326867
# iteration 159 and prediction = 28552.399737947744
# iteration 160 and prediction = 28518.275391424933
# iteration 161 and prediction = 28524.329274039384
# iteration 162 and prediction = 28500.741940609852
# iteration 163 and prediction = 28549.410697173378
# iteration 164 and prediction = 28360.025147010198
# iteration 165 and prediction = 28386.42076221513
# iteration 166 and prediction = 28293.109245853488
# iteration 167 and prediction = 28359.230331829804
# iteration 168 and prediction = 27993.484078602014
# iteration 169 and prediction = 27829.580928356874
# iteration 170 and prediction = 27200.877096621523
# iteration 171 and prediction = 27125.94057010115
# iteration 172 and prediction = 26849.15187423446
# iteration 173 and prediction = 26993.047055701332
# iteration 174 and prediction = 27239.482941697817
# iteration 175 and prediction = 27480.756182913596
# iteration 176 and prediction = 27888.246989505955
# iteration 177 and prediction = 27970.53147114767
# iteration 178 and prediction = 28546.816796488707
# iteration 179 and prediction = 28819.33267478062
# iteration 180 and prediction = 28998.299133464
# iteration 181 and prediction = 28973.580475022776
# iteration 182 and prediction = 29212.431321397627
# iteration 183 and prediction = 29530.956782468318
# iteration 184 and prediction = 29555.172061051446
# iteration 185 and prediction = 29470.494116494174
# iteration 186 and prediction = 29491.56318846403
# iteration 187 and prediction = 29347.24553832083
# iteration 188 and prediction = 29534.76301868891
# iteration 189 and prediction = 29752.29678048016
# iteration 190 and prediction = 29741.251801873354
# iteration 191 and prediction = 29836.90230347536
# iteration 192 and prediction = 29683.493899071338
# iteration 193 and prediction = 29799.47740670252
# iteration 194 and prediction = 29816.614251383005
# iteration 195 and prediction = 29882.55193186997
# iteration 196 and prediction = 30052.133731032165
# iteration 197 and prediction = 29994.541709392717
# iteration 198 and prediction = 30105.903247417293
# iteration 199 and prediction = 30048.32347237575
# iteration 200 and prediction = 30064.843419431756
# iteration 201 and prediction = 30059.00495444807
# iteration 202 and prediction = 29944.62629296396
# iteration 203 and prediction = 30125.189093929253
# iteration 204 and prediction = 30083.740189090964
# iteration 205 and prediction = 30210.969549341797
# iteration 206 and prediction = 30159.567705173187
# iteration 207 and prediction = 30190.299395218677
# iteration 208 and prediction = 30093.433917067105
# iteration 209 and prediction = 30136.95851318548
# iteration 210 and prediction = 30161.622396760096
# iteration 211 and prediction = 30284.624228190914
# iteration 212 and prediction = 30272.678040445157
# iteration 213 and prediction = 30346.354589784165
# iteration 214 and prediction = 30458.43084220404
# iteration 215 and prediction = 30290.387395431797
# iteration 216 and prediction = 30396.643225329444
# iteration 217 and prediction = 30595.938344372404
# iteration 218 and prediction = 30763.523702243656
# iteration 219 and prediction = 30896.286797562396
# iteration 220 and prediction = 30895.386141024705
# iteration 221 and prediction = 30977.693026619694
# iteration 222 and prediction = 30990.7630140119
# iteration 223 and prediction = 30978.063002276842
# iteration 224 and prediction = 30895.62074522038
# iteration 225 and prediction = 30873.06411673183
# iteration 226 and prediction = 30914.6140643239
# iteration 227 and prediction = 31051.7782295773
# iteration 228 and prediction = 31075.702157162814
# iteration 229 and prediction = 31022.131109173188
# iteration 230 and prediction = 31000.95423846122
# iteration 231 and prediction = 30969.41832037887
# iteration 232 and prediction = 30621.31114164252
# iteration 233 and prediction = 30729.923256482896
# iteration 234 and prediction = 30297.764880135815
# iteration 235 and prediction = 30396.48106475766
# iteration 236 and prediction = 30548.633628333897
# iteration 237 and prediction = 30583.873500061447
# iteration 238 and prediction = 30847.927056284017
# iteration 239 and prediction = 30910.10187895266
# iteration 240 and prediction = 31129.94846586478
# iteration 241 and prediction = 31195.848247005037
# iteration 242 and prediction = 31276.007065393584
# iteration 243 and prediction = 31336.703476649327
# iteration 244 and prediction = 31365.929638580612
# iteration 245 and prediction = 31438.844010034663
# iteration 246 and prediction = 31505.99359459593
# iteration 247 and prediction = 31470.30148026255
# iteration 248 and prediction = 31493.801560233616
# iteration 249 and prediction = 31496.061686982343
# iteration 250 and prediction = 31516.36917525579
# iteration 251 and prediction = 31753.44487692339
# iteration 252 and prediction = 31482.841724931925
# iteration 253 and prediction = 31266.504238374277
# iteration 254 and prediction = 31486.21078872355
# iteration 255 and prediction = 31360.22468601082
# iteration 256 and prediction = 31369.15946009468
# iteration 257 and prediction = 31129.89721553526
# iteration 258 and prediction = 31390.534464015367
# iteration 259 and prediction = 31550.886552569707
# iteration 260 and prediction = 31640.75821070741
# iteration 261 and prediction = 31971.416017398205
# iteration 262 and prediction = 32123.430613468216
# iteration 263 and prediction = 32414.264344472584
# iteration 264 and prediction = 32608.671462568345
# iteration 265 and prediction = 32632.316609498776
# iteration 266 and prediction = 32828.4795005685
# iteration 267 and prediction = 32764.976220650155
# iteration 268 and prediction = 32699.95868510663
# iteration 269 and prediction = 32739.98038053333
# iteration 270 and prediction = 32544.217676556134
# iteration 271 and prediction = 32547.79245385779
# iteration 272 and prediction = 32591.693782268565
# iteration 273 and prediction = 32836.47395363095
# iteration 274 and prediction = 32952.239680683844
# iteration 275 and prediction = 32964.14985503817
# iteration 276 and prediction = 32962.10912378042
# iteration 277 and prediction = 33055.40387301554
# iteration 278 and prediction = 33278.54934632559
# iteration 279 and prediction = 33289.25194361067
# iteration 280 and prediction = 33361.49658774215
# iteration 281 and prediction = 33409.60669380593
# iteration 282 and prediction = 33594.746028335794
# iteration 283 and prediction = 33619.3060667886
# iteration 284 and prediction = 33632.60516085588
# iteration 285 and prediction = 33677.28071352056
# iteration 286 and prediction = 33850.706430185186
# iteration 287 and prediction = 33984.83290580727
# iteration 288 and prediction = 33987.95228628104
# iteration 289 and prediction = 33886.52301400865
# iteration 290 and prediction = 34048.791383832235
# iteration 291 and prediction = 33866.81724973041
# iteration 292 and prediction = 34021.8042782648
# iteration 293 and prediction = 33955.591749579115
# iteration 294 and prediction = 33981.69994559981
# iteration 295 and prediction = 33897.63677476097
# iteration 296 and prediction = 34002.85827939298
# iteration 297 and prediction = 33904.8249723978
# iteration 298 and prediction = 34050.158460508246
# iteration 299 and prediction = 34048.75071804622
# iteration 300 and prediction = 34144.209062290436
# iteration 301 and prediction = 34335.11955847979
# iteration 302 and prediction = 34507.146453601395
# iteration 303 and prediction = 34573.6896151725
# iteration 304 and prediction = 34378.665673154974
# iteration 305 and prediction = 33993.331446626966
# iteration 306 and prediction = 34137.31951190487
# iteration 307 and prediction = 34232.06265840232
# iteration 308 and prediction = 34265.90539310367
# iteration 309 and prediction = 34152.449042965425
# iteration 310 and prediction = 34034.62086515436
# iteration 311 and prediction = 34102.462301702675
# iteration 312 and prediction = 34143.89613276563
# iteration 313 and prediction = 34267.82613226697
# iteration 314 and prediction = 34256.95091229442
# iteration 315 and prediction = 34285.130019832715
# iteration 316 and prediction = 34374.910235644435
# iteration 317 and prediction = 34422.89704777918
# iteration 318 and prediction = 34465.22584336509
# iteration 319 and prediction = 34507.960459887945
# iteration 320 and prediction = 34537.68350050454
# iteration 321 and prediction = 34548.77705510642
# iteration 322 and prediction = 34654.51313950935
# iteration 323 and prediction = 34605.13040399997
# iteration 324 and prediction = 34614.69765482956
# iteration 325 and prediction = 34520.15209957023
# iteration 326 and prediction = 34516.72515390748
# iteration 327 and prediction = 34504.27039514971
# iteration 328 and prediction = 34447.49935053725
# iteration 329 and prediction = 34389.38319985611
# iteration 330 and prediction = 34215.853199552475
# iteration 331 and prediction = 34059.27724137019
# iteration 332 and prediction = 33699.340165833935
# iteration 333 and prediction = 33919.17663974786
# iteration 334 and prediction = 33881.868714258155
# iteration 335 and prediction = 33891.79411024003
# iteration 336 and prediction = 34069.30592258182
# iteration 337 and prediction = 34194.57258552017
# iteration 338 and prediction = 34204.249745619105
# iteration 339 and prediction = 34245.284035487464
# iteration 340 and prediction = 34356.41786312436
# iteration 341 and prediction = 34473.561233035354
# iteration 342 and prediction = 34600.410795091244
# iteration 343 and prediction = 34541.44305886982
# iteration 344 and prediction = 34627.12453367164
# iteration 345 and prediction = 34484.37894390874
# iteration 346 and prediction = 34734.63361314811
# iteration 347 and prediction = 34804.27486173045
# iteration 348 and prediction = 34816.677040729664
# iteration 349 and prediction = 34880.36929298746
# iteration 350 and prediction = 34903.06109978922
# iteration 351 and prediction = 34775.891396762156
# iteration 352 and prediction = 34374.576921878164
# iteration 353 and prediction = 34574.59483635239
# iteration 354 and prediction = 34647.61765053102
# iteration 355 and prediction = 34722.634064766695
# iteration 356 and prediction = 34898.027336005805
# iteration 357 and prediction = 34954.55102398409
# iteration 358 and prediction = 34990.108853843434
# iteration 359 and prediction = 34942.19749031624
# iteration 360 and prediction = 35021.373137315466
# iteration 361 and prediction = 34954.262019627095
# iteration 362 and prediction = 34906.7232058045
# iteration 363 and prediction = 35041.14556106125
# iteration 364 and prediction = 34858.82691101966
# iteration 365 and prediction = 35031.862959144375
# iteration 366 and prediction = 35077.05752150583
# iteration 367 and prediction = 35064.41666579547
# iteration 368 and prediction = 35188.67714513343
# iteration 369 and prediction = 35296.04428194721
# iteration 370 and prediction = 35370.21304070891
# iteration 371 and prediction = 35425.6742992546
# iteration 372 and prediction = 35501.922626024236
# iteration 373 and prediction = 35389.2304913699
# iteration 374 and prediction = 35184.632785422524
# iteration 375 and prediction = 35092.585172903775
# iteration 376 and prediction = 35141.04496529012
# iteration 377 and prediction = 35243.72402977301
# iteration 378 and prediction = 35285.050184314045
# iteration 379 and prediction = 35334.6230794431
# iteration 380 and prediction = 35247.327858509954
# iteration 381 and prediction = 35383.99676914638
# iteration 382 and prediction = 35349.59458669563
# iteration 383 and prediction = 35361.98515285255
# iteration 384 and prediction = 35335.09834493743
# iteration 385 and prediction = 35394.77458856108
# iteration 386 and prediction = 35406.75870582228
# iteration 387 and prediction = 35380.999866417354
# iteration 388 and prediction = 35233.51905154119
# iteration 389 and prediction = 35170.89021179626
# iteration 390 and prediction = 35034.22573630188
# iteration 391 and prediction = 34852.38104764714
# iteration 392 and prediction = 34930.40449192996
# iteration 393 and prediction = 34720.42482591825
# iteration 394 and prediction = 34845.41904130469
# iteration 395 and prediction = 34766.57746431346
# iteration 396 and prediction = 34683.35729072624
# iteration 397 and prediction = 34335.42576924662
# iteration 398 and prediction = 34212.99750375215
# iteration 399 and prediction = 34293.07094742999
# iteration 400 and prediction = 34538.92640287199
# iteration 401 and prediction = 34611.32916456298
# iteration 402 and prediction = 34725.71045064416
# iteration 403 and prediction = 34441.79141888926
# iteration 404 and prediction = 34496.63374609185
# iteration 405 and prediction = 34125.12946693677
# iteration 406 and prediction = 34355.240153730534
# iteration 407 and prediction = 34110.97903326105
# iteration 408 and prediction = 34294.032712625216
# iteration 409 and prediction = 34323.5825866955
# iteration 410 and prediction = 34534.48452524285
# iteration 411 and prediction = 34590.13962076587
# iteration 412 and prediction = 34507.609491730465
# iteration 413 and prediction = 34451.81434371973
# iteration 414 and prediction = 34431.505717713066
# iteration 415 and prediction = 34695.538300327324
# iteration 416 and prediction = 34951.55089660633
# iteration 417 and prediction = 35022.43649055206
# iteration 418 and prediction = 35232.18783929822
# iteration 419 and prediction = 35349.686536155205
# iteration 420 and prediction = 35437.469828537345
# iteration 421 and prediction = 35534.8738302129
# iteration 422 and prediction = 35601.02532884853
# iteration 423 and prediction = 35659.66187477743
# iteration 424 and prediction = 35542.30627099453
# iteration 425 and prediction = 35675.618558143055
# iteration 426 and prediction = 35713.9133271321
# iteration 427 and prediction = 35805.67197063125
# iteration 428 and prediction = 35916.13291250996
# iteration 429 and prediction = 36000.5311584372
# iteration 430 and prediction = 36037.47196954875
# iteration 431 and prediction = 36179.346861706035
# iteration 432 and prediction = 36263.36541581384
# iteration 433 and prediction = 36263.23355044911
# iteration 434 and prediction = 36155.44554679886
# iteration 435 and prediction = 36054.92236162951
# iteration 436 and prediction = 36113.293920656906
# iteration 437 and prediction = 36085.96660827794
# iteration 438 and prediction = 36129.02128141313
# iteration 439 and prediction = 36010.02033611289
# iteration 440 and prediction = 35966.258601072725
# iteration 441 and prediction = 35786.661313656994
# iteration 442 and prediction = 35752.66454313203
# iteration 443 and prediction = 35808.975578040976
# iteration 444 and prediction = 35792.28468932486
# iteration 445 and prediction = 35311.66650029882
# iteration 446 and prediction = 35372.282086790845
# iteration 447 and prediction = 34870.17112277098
# iteration 448 and prediction = 34572.39324594844
# iteration 449 and prediction = 34739.63029625494
# iteration 450 and prediction = 34600.33614190368
# iteration 451 and prediction = 35017.179232598646
# iteration 452 and prediction = 35283.363320806966
# iteration 453 and prediction = 35428.44166391385
# iteration 454 and prediction = 35567.957103360284
# iteration 455 and prediction = 35706.52954535792
# iteration 456 and prediction = 35620.43120886302
# iteration 457 and prediction = 35598.027028953096
# iteration 458 and prediction = 35775.8588429366
# iteration 459 and prediction = 35788.035133387544
# iteration 460 and prediction = 35548.91374224953
# iteration 461 and prediction = 35281.10709946209
# iteration 462 and prediction = 35481.67659976313
# iteration 463 and prediction = 35584.48888914558
# iteration 464 and prediction = 35762.14959397446
# iteration 465 and prediction = 35810.431723815695
# iteration 466 and prediction = 36046.14241828355
# iteration 467 and prediction = 36160.651872780516
# iteration 468 and prediction = 36290.368803448786
# iteration 469 and prediction = 36297.82465450512
# iteration 470 and prediction = 36303.03960281111
# iteration 471 and prediction = 36450.62459195309
# iteration 472 and prediction = 36593.85798386327
# iteration 473 and prediction = 36437.46529414856
# iteration 474 and prediction = 36371.97741364972
# iteration 475 and prediction = 36307.66628809197
# iteration 476 and prediction = 36198.47246345774
# iteration 477 and prediction = 36275.56677580444
# iteration 478 and prediction = 36262.82427885973
# iteration 479 and prediction = 36185.70901724112
# iteration 480 and prediction = 36064.77887793494
# iteration 481 and prediction = 36013.83669065006
# iteration 482 and prediction = 35681.67490869897
# iteration 483 and prediction = 35433.36500296969
# iteration 484 and prediction = 35128.22385018807
# iteration 485 and prediction = 34759.4198382282
# iteration 486 and prediction = 34685.831862842264
# iteration 487 and prediction = 34514.812900462646
# iteration 488 and prediction = 34393.383345678085
# iteration 489 and prediction = 34324.01412221309
# iteration 490 and prediction = 34572.99647327531
# iteration 491 and prediction = 34821.70758728027
# iteration 492 and prediction = 35066.24791169833
# iteration 493 and prediction = 35291.15338022835
# iteration 494 and prediction = 35094.095010735735
# iteration 495 and prediction = 35133.609680408095
# iteration 496 and prediction = 35091.569600399096
# iteration 497 and prediction = 35304.91665724762
# iteration 498 and prediction = 35511.255579561766
# iteration 499 and prediction = 35279.55120125746
# iteration 500 and prediction = 35043.80931936847
# iteration 501 and prediction = 34847.26799368396
# iteration 502 and prediction = 34991.89048999025
# iteration 503 and prediction = 34942.848948149905
# iteration 504 and prediction = 34607.28207207351
# iteration 505 and prediction = 34426.61885130867
# iteration 506 and prediction = 34021.83633099539
# iteration 507 and prediction = 33667.06611964782
# iteration 508 and prediction = 33564.233198856906
# iteration 509 and prediction = 33895.116462430895
# iteration 510 and prediction = 33818.38553705741
# iteration 511 and prediction = 33551.36441421415
# iteration 512 and prediction = 33822.770323850724
# iteration 513 and prediction = 33715.34272885848
# iteration 514 and prediction = 33699.931763275184
# iteration 515 and prediction = 33220.32131524658
# iteration 516 and prediction = 33024.06940074073
# iteration 517 and prediction = 33265.09134565599
# iteration 518 and prediction = 33146.86908947579
# iteration 519 and prediction = 33087.463818979006
# iteration 520 and prediction = 33033.20951955661
# iteration 521 and prediction = 33320.240575753065
# iteration 522 and prediction = 33665.98604766536
# iteration 523 and prediction = 34000.13236528136
# iteration 524 and prediction = 34304.541854679
# iteration 525 and prediction = 34317.811408574446
# iteration 526 and prediction = 34560.50703842104
# iteration 527 and prediction = 34353.71928278716
# iteration 528 and prediction = 34598.45188237887
# iteration 529 and prediction = 34676.25191963164
# iteration 530 and prediction = 34790.59646319976
# iteration 531 and prediction = 35046.95319143255
# iteration 532 and prediction = 35048.235293265425
# iteration 533 and prediction = 34825.738399439295
# iteration 534 and prediction = 34891.0250942133
# iteration 535 and prediction = 34874.22851930212
# iteration 536 and prediction = 34760.882638550516
# iteration 537 and prediction = 34653.5267385252
# iteration 538 and prediction = 34644.83290622088
# iteration 539 and prediction = 34699.310091966705
# iteration 540 and prediction = 34469.79076921211
# iteration 541 and prediction = 34401.56852806359
# iteration 542 and prediction = 34522.740183418726
# iteration 543 and prediction = 34445.24326217036
# iteration 544 and prediction = 34462.82047066762
# iteration 545 and prediction = 34708.47305996511
# iteration 546 and prediction = 34878.22437462391
# iteration 547 and prediction = 34777.85170905749
# iteration 548 and prediction = 34251.2683125315
# iteration 549 and prediction = 34295.56922745897
# iteration 550 and prediction = 33698.94623670144
# iteration 551 and prediction = 33679.819953051265
# iteration 552 and prediction = 33861.98509191627
# iteration 553 and prediction = 33302.85580276613
# iteration 554 and prediction = 33371.60997125203
# iteration 555 and prediction = 33219.38715262369
# iteration 556 and prediction = 33734.81258453133
# iteration 557 and prediction = 33206.07394575269
# iteration 558 and prediction = 33162.04924786608
# iteration 559 and prediction = 32680.510004722422
# iteration 560 and prediction = 32522.045709092607
# iteration 561 and prediction = 32226.21841241637
# iteration 562 and prediction = 32047.920920882945
# iteration 563 and prediction = 32212.59528067135
# iteration 564 and prediction = 32191.004808384856
# iteration 565 and prediction = 32459.17713905269
# iteration 566 and prediction = 31840.498558508174
# iteration 567 and prediction = 31674.80190828348
# iteration 568 and prediction = 31521.355697573068
# iteration 569 and prediction = 31764.779471230806
# iteration 570 and prediction = 31824.998741797313
# iteration 571 and prediction = 31964.057572542602
# iteration 572 and prediction = 32300.39221536021
# iteration 573 and prediction = 32701.16210034343
# iteration 574 and prediction = 32719.992324571103
# iteration 575 and prediction = 32750.67568359554
# iteration 576 and prediction = 32997.210780454414
# iteration 577 and prediction = 32861.13547603018
# iteration 578 and prediction = 33080.62604781173
# iteration 579 and prediction = 32913.422251167605
# iteration 580 and prediction = 32581.595441588634
# iteration 581 and prediction = 32026.760092705466
# iteration 582 and prediction = 31332.237968162226
# iteration 583 and prediction = 31032.698049807143
# iteration 584 and prediction = 30968.314972324835
# iteration 585 and prediction = 30421.056468907544
# iteration 586 and prediction = 30320.181352759297
# iteration 587 and prediction = 30492.709525441613
# iteration 588 and prediction = 30449.273136547206
# iteration 589 and prediction = 30621.64023542852
# iteration 590 and prediction = 31069.5361150228
# iteration 591 and prediction = 31128.734456287988
# iteration 592 and prediction = 30999.417317996365
# iteration 593 and prediction = 31029.05386754645
# iteration 594 and prediction = 30855.88322537484
# iteration 595 and prediction = 31057.735544953044
# iteration 596 and prediction = 30952.06899300701
# iteration 597 and prediction = 31025.450290125125
# iteration 598 and prediction = 31222.60704905005
# iteration 599 and prediction = 31211.2704883789
# iteration 600 and prediction = 31195.467296067047
# iteration 601 and prediction = 31068.43909405242
# iteration 602 and prediction = 30924.094521219155
# iteration 603 and prediction = 30813.863417895645
# iteration 604 and prediction = 31125.539388638386
# iteration 605 and prediction = 31012.10336951894
# iteration 606 and prediction = 31516.92917516754
# iteration 607 and prediction = 31565.17952195689
# iteration 608 and prediction = 31790.89077766088
# iteration 609 and prediction = 31782.806077911955
# iteration 610 and prediction = 31865.295724126874
# iteration 611 and prediction = 31778.690656949373
# iteration 612 and prediction = 32038.089552931368
# iteration 613 and prediction = 32238.309701425573
# iteration 614 and prediction = 32524.32511020703
# iteration 615 and prediction = 32580.314968044047
# iteration 616 and prediction = 32431.47655913767
# iteration 617 and prediction = 32681.133951545184
# iteration 618 and prediction = 32625.388505116007
# iteration 619 and prediction = 32737.42483897209
# iteration 620 and prediction = 32766.219992021932
# iteration 621 and prediction = 32738.041280941772
# iteration 622 and prediction = 33087.66614598104
# iteration 623 and prediction = 33114.19898846136
# iteration 624 and prediction = 33470.022094686115
# iteration 625 and prediction = 33613.86040136273
# iteration 626 and prediction = 33847.83367733668
# iteration 627 and prediction = 33849.26351993051
# iteration 628 and prediction = 33905.31087173118
# iteration 629 and prediction = 33764.07076969656
# iteration 630 and prediction = 33390.47054381838
# iteration 631 and prediction = 33227.797151354716
# iteration 632 and prediction = 33143.958960369266
# iteration 633 and prediction = 33274.39005318431
# iteration 634 and prediction = 32683.089386585252
# iteration 635 and prediction = 32521.935759561035
# iteration 636 and prediction = 32166.271325561334
# iteration 637 and prediction = 31900.410733725992
# iteration 638 and prediction = 31888.36616254883
# iteration 639 and prediction = 31567.98470378508
# iteration 640 and prediction = 31437.751152696157
# iteration 641 and prediction = 31586.2619741459
# iteration 642 and prediction = 31651.021923106517
# iteration 643 and prediction = 31948.30059439332
# iteration 644 and prediction = 32102.421841336494
# iteration 645 and prediction = 31452.865840574043
# iteration 646 and prediction = 31458.428229145706
# iteration 647 and prediction = 31168.039792241503
# iteration 648 and prediction = 31065.214864222264
# iteration 649 and prediction = 31115.129874081238
# iteration 650 and prediction = 30852.22329363167
# iteration 651 and prediction = 30559.888768352084
# iteration 652 and prediction = 30376.031281120086
# iteration 653 and prediction = 29973.909997238163
# iteration 654 and prediction = 29708.220545486518
# iteration 655 and prediction = 29467.397086851804
# iteration 656 and prediction = 29691.736844179763
# iteration 657 and prediction = 29376.28017890949
# iteration 658 and prediction = 29090.715609175022
# iteration 659 and prediction = 29425.757697857538
# iteration 660 and prediction = 29850.382378651095
# iteration 661 and prediction = 29984.487522226464
# iteration 662 and prediction = 29901.67809151118
# iteration 663 and prediction = 29534.855685817256
# iteration 664 and prediction = 29446.088637013396
# iteration 665 and prediction = 29360.22640715495
# iteration 666 and prediction = 29312.108685606527
# iteration 667 and prediction = 29773.857953572784
# iteration 668 and prediction = 29551.478440233237
# iteration 669 and prediction = 29983.082768442575
# iteration 670 and prediction = 30171.97717245209
# iteration 671 and prediction = 30227.589135559152
# iteration 672 and prediction = 30280.96363008537
# iteration 673 and prediction = 30704.751000301167
# iteration 674 and prediction = 31040.334106571427
# iteration 675 and prediction = 31402.395974205
# iteration 676 and prediction = 31524.729154915785
# iteration 677 and prediction = 31763.245311967796
# iteration 678 and prediction = 32327.27316550622
# iteration 679 and prediction = 32384.577548487443
# iteration 680 and prediction = 32506.49494159315
# iteration 681 and prediction = 32240.625738303395
# iteration 682 and prediction = 32148.91777504659
# iteration 683 and prediction = 32343.614527845195
# iteration 684 and prediction = 32568.35271757943
# iteration 685 and prediction = 32862.37099044455
# iteration 686 and prediction = 32558.227332200942
# iteration 687 and prediction = 33317.17570557733
# iteration 688 and prediction = 33348.71152486191
# iteration 689 and prediction = 33422.18329869373
# iteration 690 and prediction = 33513.20069642196
# iteration 691 and prediction = 33467.3703049888
# iteration 692 and prediction = 33538.374375846906
# iteration 693 and prediction = 33639.06460594238
# iteration 694 and prediction = 33632.541301383164
# iteration 695 and prediction = 33922.08851777294
# iteration 696 and prediction = 33983.911995327995
# iteration 697 and prediction = 34178.521411646754
# iteration 698 and prediction = 33918.13712377363
# iteration 699 and prediction = 33940.7375657925
# iteration 700 and prediction = 34326.133409105394
# iteration 701 and prediction = 34246.92705906619
# iteration 702 and prediction = 34381.27426184694
# iteration 703 and prediction = 34078.98426418336
# iteration 704 and prediction = 33860.50880027412
# iteration 705 and prediction = 33790.98964451686
# iteration 706 and prediction = 33800.73216085674
# iteration 707 and prediction = 33624.84200457834
# iteration 708 and prediction = 33908.80340351419
# iteration 709 and prediction = 33944.93649678962
# iteration 710 and prediction = 33944.60691518439
# iteration 711 and prediction = 33504.421111196636
# iteration 712 and prediction = 33275.79311234392
# iteration 713 and prediction = 33048.35955802013
# iteration 714 and prediction = 33009.75611421013
# iteration 715 and prediction = 33262.88102001176
# iteration 716 and prediction = 33055.293266138695
# iteration 717 and prediction = 33203.78963999838
# iteration 718 and prediction = 33188.51158929057
# iteration 719 and prediction = 32989.951866633426
# iteration 720 and prediction = 33203.13201858349
# iteration 721 and prediction = 33097.81135629405
# iteration 722 and prediction = 33153.03601350739
# iteration 723 and prediction = 33216.01440546691
# iteration 724 and prediction = 33011.279646454874
# iteration 725 and prediction = 33450.398068194096
# iteration 726 and prediction = 33358.67545462682
# iteration 727 and prediction = 33578.97440171248
# iteration 728 and prediction = 33758.77043110089
# iteration 729 and prediction = 33933.10998105342
# iteration 730 and prediction = 34108.1033718993
# iteration 731 and prediction = 33920.79737608042
# iteration 732 and prediction = 33590.64450465943
# iteration 733 and prediction = 33366.92350859004
# iteration 734 and prediction = 33439.88050655928
# iteration 735 and prediction = 33554.57185901087
# iteration 736 and prediction = 33633.86860852774
# iteration 737 and prediction = 33677.939587873654
# iteration 738 and prediction = 33817.92173393878
# iteration 739 and prediction = 33867.440203427715
# iteration 740 and prediction = 33756.12268236673
# iteration 741 and prediction = 33982.47719757436
# iteration 742 and prediction = 33977.97405402903
# iteration 743 and prediction = 34018.996827856296
# iteration 744 and prediction = 33954.090689855984
# iteration 745 and prediction = 33922.95580689612
# iteration 746 and prediction = 34078.00861151458
# iteration 747 and prediction = 33953.89526203139
# iteration 748 and prediction = 33836.65836361923
# iteration 749 and prediction = 33896.03196086576
# iteration 750 and prediction = 34082.661385276115
# iteration 751 and prediction = 34039.58900681448
# iteration 752 and prediction = 34100.27327882623
# iteration 753 and prediction = 33837.06467489547
# iteration 754 and prediction = 33903.39864638904
# iteration 755 and prediction = 33432.413480219475
# iteration 756 and prediction = 33339.400460163706
# iteration 757 and prediction = 33280.90271609333
# iteration 758 and prediction = 33022.435614410504
# iteration 759 and prediction = 33041.83764276525
# iteration 760 and prediction = 32812.80890795131
# iteration 761 and prediction = 32791.357196570774
# iteration 762 and prediction = 32946.77130732334
# iteration 763 and prediction = 33158.82787448582
# iteration 764 and prediction = 33268.55454517303
# iteration 765 and prediction = 32976.99267743202
# iteration 766 and prediction = 32946.90267812257
# iteration 767 and prediction = 32544.665694361538
# iteration 768 and prediction = 32285.491231312146
# iteration 769 and prediction = 32109.57226415954
# iteration 770 and prediction = 32197.762624844683
# iteration 771 and prediction = 32002.46768958138
# iteration 772 and prediction = 32213.00399263422
# iteration 773 and prediction = 31946.42693051097
# iteration 774 and prediction = 32198.717266518466
# iteration 775 and prediction = 32352.923761404694
# iteration 776 and prediction = 32099.541945421555
# iteration 777 and prediction = 32182.631752642545
# iteration 778 and prediction = 32185.832649732056
# iteration 779 and prediction = 32326.21281815546
# iteration 780 and prediction = 32341.79288666325
# iteration 781 and prediction = 32543.137998945916
# iteration 782 and prediction = 32677.80064296933
# iteration 783 and prediction = 32980.671051961144
# iteration 784 and prediction = 33258.64872092213
# iteration 785 and prediction = 33243.56061010081
# iteration 786 and prediction = 33376.84740372416
# iteration 787 and prediction = 33390.71918624053
# iteration 788 and prediction = 33491.70551194827
# iteration 789 and prediction = 33581.70623949117
# iteration 790 and prediction = 33581.988643796205
# iteration 791 and prediction = 33850.229597891856
# iteration 792 and prediction = 33787.11251690368
# iteration 793 and prediction = 33915.23229970358
# iteration 794 and prediction = 33915.77184546222
# iteration 795 and prediction = 33888.727024673826
# iteration 796 and prediction = 33841.79117005187
# iteration 797 and prediction = 33829.538085423286
# iteration 798 and prediction = 33863.1998893965
# iteration 799 and prediction = 33657.33586534198
# iteration 800 and prediction = 33502.37469278232
# iteration 801 and prediction = 33751.277052757105
# iteration 802 and prediction = 33888.67199909265
# iteration 803 and prediction = 33950.32730286624
# iteration 804 and prediction = 33767.621030753435
# iteration 805 and prediction = 33595.73949538264
# iteration 806 and prediction = 33370.057445132945
# iteration 807 and prediction = 33625.84005462908
# iteration 808 and prediction = 33559.95370042618
# iteration 809 and prediction = 33580.20149210869
# iteration 810 and prediction = 33549.88083197808
# iteration 811 and prediction = 33403.55261857656
# iteration 812 and prediction = 33392.01049719463
# iteration 813 and prediction = 33373.46769702168
# iteration 814 and prediction = 33161.74877723061
# iteration 815 and prediction = 33390.377764944395
# iteration 816 and prediction = 33410.68434551788
# iteration 817 and prediction = 33413.40990365234
# iteration 818 and prediction = 33339.98739192728
# iteration 819 and prediction = 33179.55586666596
# iteration 820 and prediction = 33004.5234440725
# iteration 821 and prediction = 32919.14816723801
# iteration 822 and prediction = 33055.92157501736
# iteration 823 and prediction = 33019.882891941954
# iteration 824 and prediction = 32961.88673912931
# iteration 825 and prediction = 33042.4771801471
# iteration 826 and prediction = 33445.85378075554
# iteration 827 and prediction = 33398.72513215633
# iteration 828 and prediction = 33505.14941464462
# iteration 829 and prediction = 33562.866669226685
# iteration 830 and prediction = 33692.068719494135
# iteration 831 and prediction = 33769.15919928767
# iteration 832 and prediction = 33914.65396400496
# iteration 833 and prediction = 34044.40298511926
# iteration 834 and prediction = 33960.05551868623
# iteration 835 and prediction = 34245.02464533578
# iteration 836 and prediction = 34192.08555092622
# iteration 837 and prediction = 34111.37366206991
# iteration 838 and prediction = 34045.111323268335
# iteration 839 and prediction = 33993.58200285342
# iteration 840 and prediction = 34097.03116139722
# iteration 841 and prediction = 34256.479982268844
# iteration 842 and prediction = 34303.364474704365
# iteration 843 and prediction = 34279.00801822835
# iteration 844 and prediction = 34062.06986922176
# iteration 845 and prediction = 33927.62811914269
# iteration 846 and prediction = 33983.77197068611
# iteration 847 and prediction = 34141.31288358374
# iteration 848 and prediction = 34225.05265737984
# iteration 849 and prediction = 34299.61655534422
# iteration 850 and prediction = 34395.35105870877
# iteration 851 and prediction = 34474.47252379274
# iteration 852 and prediction = 34732.712640528836
# iteration 853 and prediction = 34848.42762012947
# iteration 854 and prediction = 35029.01828435346
# iteration 855 and prediction = 35088.03936407746
# iteration 856 and prediction = 35249.405679069794
# iteration 857 and prediction = 35311.3765171157
# iteration 858 and prediction = 35407.60625816998
# iteration 859 and prediction = 35299.611181579654
# iteration 860 and prediction = 35419.882931072134
# iteration 861 and prediction = 35468.98073171228
# iteration 862 and prediction = 35547.49714561598
# iteration 863 and prediction = 35365.572736168324
# iteration 864 and prediction = 35321.94665483959
# iteration 865 and prediction = 35183.50659913484
# iteration 866 and prediction = 35401.693362099046
# iteration 867 and prediction = 35293.83321447136
# iteration 868 and prediction = 35219.01783636448
# iteration 869 and prediction = 35219.81932575893
# iteration 870 and prediction = 35252.21640952852
# iteration 871 and prediction = 35281.66108793009
# iteration 872 and prediction = 35073.46141469352
# iteration 873 and prediction = 34944.30291877049
# iteration 874 and prediction = 34708.71947406843
# iteration 875 and prediction = 34654.583535113554
# iteration 876 and prediction = 34574.029141591476
# iteration 877 and prediction = 34428.923419405415
# iteration 878 and prediction = 34510.38949140557
# iteration 879 and prediction = 34241.79175246311
# iteration 880 and prediction = 34386.333619403515
# iteration 881 and prediction = 34461.08441570974
# iteration 882 and prediction = 34666.66835325021
# iteration 883 and prediction = 34750.550137713944
# iteration 884 and prediction = 34691.317991724674
# iteration 885 and prediction = 34792.719581131256
# iteration 886 and prediction = 34667.99073084823
# iteration 887 and prediction = 34562.811614327
# iteration 888 and prediction = 34565.83450418594
# iteration 889 and prediction = 34566.938558274196
# iteration 890 and prediction = 34634.97681819414
# iteration 891 and prediction = 34621.631498356786
# iteration 892 and prediction = 34594.63973018261
# iteration 893 and prediction = 34792.28088770735
# iteration 894 and prediction = 34626.12637149756
# iteration 895 and prediction = 34670.52622729408
# iteration 896 and prediction = 34569.16549141158
# iteration 897 and prediction = 34513.489595967956
# iteration 898 and prediction = 34275.36533055172
# iteration 899 and prediction = 34155.44130570997
# iteration 900 and prediction = 34112.88942856883
# iteration 901 and prediction = 33835.25944804294
# iteration 902 and prediction = 33753.269534782914
# iteration 903 and prediction = 33737.728631676415
# iteration 904 and prediction = 33605.565152796
# iteration 905 and prediction = 33554.91278386741
# iteration 906 and prediction = 33236.21565605809
# iteration 907 and prediction = 33270.07622755006
# iteration 908 and prediction = 33183.524324824895
# iteration 909 and prediction = 33345.3701152939
# iteration 910 and prediction = 33468.99390238917
# iteration 911 and prediction = 33586.31198593795
# iteration 912 and prediction = 33682.997556186274
# iteration 913 and prediction = 33613.33222478935
# iteration 914 and prediction = 33659.47879280422
# iteration 915 and prediction = 33844.01109956458
# iteration 916 and prediction = 33875.49236737516
# iteration 917 and prediction = 33739.721766444025
# iteration 918 and prediction = 33575.3449283092
# iteration 919 and prediction = 33351.77741023295
# iteration 920 and prediction = 33173.448228013396
# iteration 921 and prediction = 33220.03330164822
# iteration 922 and prediction = 33105.40805879462
# iteration 923 and prediction = 32952.25669222021
# iteration 924 and prediction = 32680.278583308263
# iteration 925 and prediction = 32913.36732458522
# iteration 926 and prediction = 32943.81292033384
# iteration 927 and prediction = 33134.622257712654
# iteration 928 and prediction = 33510.14611307498
# iteration 929 and prediction = 33716.09409768485
# iteration 930 and prediction = 33874.749608260485
# iteration 931 and prediction = 33981.40372377146
# iteration 932 and prediction = 34007.11525951406
# iteration 933 and prediction = 33925.45529855345
# iteration 934 and prediction = 34157.21057727134
# iteration 935 and prediction = 34199.913609894335
# iteration 936 and prediction = 34562.09536411237
# iteration 937 and prediction = 34716.45341984226
# iteration 938 and prediction = 34788.84175015399
# iteration 939 and prediction = 34858.78173310227
# iteration 940 and prediction = 34999.29845080274
# iteration 941 and prediction = 35007.066455048305
# iteration 942 and prediction = 35163.12518300339
# iteration 943 and prediction = 35248.444741075975
# iteration 944 and prediction = 35269.37187695816
# iteration 945 and prediction = 35348.54787316677
# iteration 946 and prediction = 35369.467208236594
# iteration 947 and prediction = 35712.415491339976
# iteration 948 and prediction = 35937.406175223005
# iteration 949 and prediction = 36019.45350488697
# iteration 950 and prediction = 36053.2635953102
# iteration 951 and prediction = 36026.19306392313
# iteration 952 and prediction = 36085.44279331518
# iteration 953 and prediction = 36166.991772265115
# iteration 954 and prediction = 36284.39803201361
# iteration 955 and prediction = 36428.988908650936
# iteration 956 and prediction = 36782.9673302591
# iteration 957 and prediction = 36957.58794650879
# iteration 958 and prediction = 37105.412526498025
# iteration 959 and prediction = 37174.26291645818
# iteration 960 and prediction = 37373.32546850109
# iteration 961 and prediction = 37132.07869338736
# iteration 962 and prediction = 37359.74913537819
# iteration 963 and prediction = 37312.29444690446
# iteration 964 and prediction = 37458.64021373703
# iteration 965 and prediction = 37546.97996118843
# iteration 966 and prediction = 37606.404220607765
# iteration 967 and prediction = 37640.475606267646
# iteration 968 and prediction = 37671.14307100684
# iteration 969 and prediction = 37507.68907461305
# iteration 970 and prediction = 37517.17653333773
# iteration 971 and prediction = 37481.51547520448
# iteration 972 and prediction = 37618.95215711908
# iteration 973 and prediction = 37525.470625070535
# iteration 974 and prediction = 37653.02666252162
# iteration 975 and prediction = 37652.90559877823
# iteration 976 and prediction = 37610.27667228898
# iteration 977 and prediction = 37472.75822596745
# iteration 978 and prediction = 37384.10705241631
# iteration 979 and prediction = 37464.8111915281
# iteration 980 and prediction = 37692.581880651065
# iteration 981 and prediction = 37814.16271738039
# iteration 982 and prediction = 37832.61197040511
# iteration 983 and prediction = 37800.46697406216
# iteration 984 and prediction = 37956.51917269091
# iteration 985 and prediction = 38002.2015715568
# iteration 986 and prediction = 38188.86728667988
# iteration 987 and prediction = 38302.513244678084
# iteration 988 and prediction = 38165.903735080385
# iteration 989 and prediction = 38418.54257128104
# iteration 990 and prediction = 38486.48409950472
# iteration 991 and prediction = 38392.678817095104
# iteration 992 and prediction = 38503.54796509188
# iteration 993 and prediction = 38566.187892068
# iteration 994 and prediction = 38646.579410753606
# iteration 995 and prediction = 38639.99305791013
# iteration 996 and prediction = 38728.60427853838
# iteration 997 and prediction = 38425.361688817204
# iteration 998 and prediction = 38507.449714951494
# iteration 999 and prediction = 38654.30196951047
# iteration 1000 and prediction = 38591.611657634625
# iteration 1001 and prediction = 38600.38786460116
# iteration 1002 and prediction = 38599.22985720376
# iteration 1003 and prediction = 38882.09188094117
# iteration 1004 and prediction = 38959.42099935322
# iteration 1005 and prediction = 38991.49334099639
# iteration 1006 and prediction = 38970.40681278448
# iteration 1007 and prediction = 38950.692096236635
# iteration 1008 and prediction = 38986.615322303864
# iteration 1009 and prediction = 39037.641000324445
# iteration 1010 and prediction = 38992.11512134466
# iteration 1011 and prediction = 38757.31482738321
# iteration 1012 and prediction = 38764.779450189235
# iteration 1013 and prediction = 38785.058129769655
# iteration 1014 and prediction = 38743.13664739451
# iteration 1015 and prediction = 38779.283413793804
# iteration 1016 and prediction = 38903.90437730767
# iteration 1017 and prediction = 38952.584358145585
# iteration 1018 and prediction = 38908.86599736254
# iteration 1019 and prediction = 38797.94626119459
# iteration 1020 and prediction = 38823.916800570274
# iteration 1021 and prediction = 38994.00067540149
# iteration 1022 and prediction = 39263.07599434018
# iteration 1023 and prediction = 39499.87835485274
# iteration 1024 and prediction = 39406.44897741194
# iteration 1025 and prediction = 39364.11322099689
# iteration 1026 and prediction = 39321.08576967833
# iteration 1027 and prediction = 39598.00703193204
# iteration 1028 and prediction = 39652.326856432985
# iteration 1029 and prediction = 39576.060321513294
# iteration 1030 and prediction = 39349.03504698208
# iteration 1031 and prediction = 39272.46744714677
# iteration 1032 and prediction = 38888.2962199009
# iteration 1033 and prediction = 39017.71726715953
# iteration 1034 and prediction = 38917.93235850996
# iteration 1035 and prediction = 38926.7430243409
# iteration 1036 and prediction = 38652.495147685055
# iteration 1037 and prediction = 38606.96390194
# iteration 1038 and prediction = 38248.74433195392
# iteration 1039 and prediction = 38042.26310642572
# iteration 1040 and prediction = 37967.38014839052
# iteration 1041 and prediction = 37866.88016033744
# iteration 1042 and prediction = 37850.19638138833
# Error for the model is 436.4378889294469

# %% [markdown]
# Thus, there is only a marginal improvement in the MSE after changing the order from (3, 1, 2) to (2, 1, 6). There is nothing much that we can do any more to beat the baseline.

# %%
final_pred_arima = pd.DataFrame(predictions, columns = test.columns, index = test.index)

# %%
plt.plot(test, color = 'red', label = 'Real Market Index')
plt.plot(final_pred_arima, color = 'blue', label = 'Predicted Market Index')
plt.title('Market Index Prediction using fine tuned ARIMA')
plt.xlabel('Time')
plt.ylabel('Dow Jones Industrial Index')
plt.xticks(rotation='vertical')
plt.legend()
plt.show()

# %% [markdown]
# # Therefore, the top models will be:
#
# 1. RIDGE REGRESSION (WITH SOLVER = 'SAG' AND ALPHA = 1): Beats the baseline model
# 2. XGB REGRESSOR (WITH ESTIMATORS = 200 AND ALPHA = 1): Beats the baseline model
# 3. ARIMA WITH ORDER (2, 1, 6): Falls slightly short of baseline model performance
#
#
#
# The following XGB Regressor models also give an RMSE roughly equal to the second model:
# - Estimators = 150 and learning rate = 0.1
# - Estimators = 150 and learning rate = 1
# - Estimators = 200 and learning rate = 0.1
# - Estimators = 250 and learning rate = 0.1
# - Estimators = 250 and learning rate = 1
# - Estimators = 300 and learning rate = 0.1
# - Estimators = 300 and learning rate = 1
